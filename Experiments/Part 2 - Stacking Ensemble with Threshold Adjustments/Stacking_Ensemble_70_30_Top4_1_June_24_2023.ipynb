# %% [markdown]
# # Import needed modules

# %%
model_count = 4
model1_name = 'ConvNeXtTiny'
model2_name = 'MobileNetV2'
model3_name = 'EfficientNetV2B3'
model4_name = 'DenseNet121'

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import system libs
import os
import time
import shutil
import pathlib
import itertools

# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# # Create needed functions

# %% [markdown]
# #### **Function to create data frame**

# %%
# Generate data paths with labels
def define_paths(dir):
    filepaths = []
    labels = []

    folds = os.listdir(dir)
    for fold in folds:
        foldpath = os.path.join(dir, fold)
        filelist = os.listdir(foldpath)

        for fold_ in filelist:
            foldpath_ = os.path.join(foldpath, fold_)
            filelist_ = os.listdir(foldpath_)

            for file_ in filelist_:
                fpath = os.path.join(foldpath_, file_)
                filepaths.append(fpath)
                labels.append(fold_)

    return filepaths, labels


# Concatenate data paths with labels into one dataframe ( to later be fitted into the model )
def define_df(files, classes):
    Fseries = pd.Series(files, name= 'filepaths')
    Lseries = pd.Series(classes, name='labels')
    return pd.concat([Fseries, Lseries], axis= 1)


# Function that create dataframe for train, and test data (stacking)
def create_df(data_dir):

    # train dataframe
    files1, classes1 = define_paths(data_dir[0])
    train_df = define_df(files1, classes1)    # d1

    # test dataframe
    files, classes = define_paths(data_dir[1])
    test_df = define_df(files, classes)       # d2

    # strat = train_df['labels']
    # train1_df, train2_df = train_test_split(train_df, train_size=0.8, shuffle=True, random_state=123, stratify=strat)  # 80% d1 train, 20% d1 test

    # strat = test_df['labels']
    # test1_df, test2_df = train_test_split(test_df, train_size=0.2, shuffle=True, random_state=123, stratify=strat) # 20% d2 train, 80% d2 test

    # train_new_df = pd.concat([train1_df,test1_df]) # train -> d1:d2 - 80:20

    # test_new_df = pd.concat([train2_df,test2_df]) # test -> d1:d2 - 20:80

    return train_df, test_df

# %% [markdown]
# #### **Function to display data sample**

# %%
def show_images(gen):
    '''
    This function take the data generator and show sample of the images
    '''

    # return classes , images to be displayed
    g_dict = gen.class_indices        # defines dictionary {'class': index}
    classes = list(g_dict.keys())     # defines list of dictionary's kays (classes), classes names : string
    images, labels = next(gen)        # get a batch size samples from the generator

    # calculate number of displayed samples
    length = len(labels)        # length of batch size
    sample = min(length, 25)    # check if sample less than 25 images

    plt.figure(figsize= (20, 20))

    for i in range(sample):
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       # scales data to range (0 - 255)
        plt.imshow(image)
        index = np.argmax(labels[i])  # get image index
        class_name = classes[index]   # get class of image
        plt.title(class_name, color= 'blue', fontsize= 12)
        plt.axis('off')
    plt.show()

# %% [markdown]
# #### **Function to plot value counts for a column in a dataframe**

# %%
def plot_label_count(df, plot_title):
    '''
    This function take df and plot labels value counts
    '''

    # Define needed variables
    vcounts = df['labels'].value_counts()
    labels = vcounts.keys().tolist()
    values = vcounts.tolist()
    lcount = len(labels)

    if lcount > 55:
        print('The number of labels is > 55, no plot will be produced')

    else:
        plot_labels(lcount, labels, values, plot_title)

def plot_labels(lcount, labels, values, plot_title):
    width = lcount * 4
    width = np.min([width, 20])

    plt.figure(figsize= (width, 5))

    form = {'family': 'serif', 'color': 'blue', 'size': 25}
    sns.barplot(labels, values)
    plt.title(f'Images per Label in {plot_title} data', fontsize= 24, color= 'blue')
    plt.xticks(rotation= 90, fontsize= 18)
    plt.yticks(fontsize= 18)
    plt.xlabel('CLASS', fontdict= form)
    yaxis_label = 'IMAGE COUNT'
    plt.ylabel(yaxis_label, fontdict= form)

    rotation = 'vertical' if lcount >= 8 else 'horizontal'
    for i in range(lcount):
        plt.text(i, values[i] / 2, str(values[i]), fontsize= 12,
                rotation= rotation, color= 'yellow', ha= 'center')

    plt.show()

# %% [markdown]
# #### **Function to create Confusion Matrix**

# %%
def plot_confusion_matrix(cm, classes, normalize= False, title= 'Confusion Matrix', cmap= plt.cm.Blues):
	'''
	This function plot confusion matrix method from sklearn package.
	'''

	plt.figure(figsize= (10, 10))
	plt.imshow(cm, interpolation= 'nearest', cmap= cmap)
	plt.title(title)
	plt.colorbar()

	tick_marks = np.arange(len(classes))
	plt.xticks(tick_marks, classes, rotation= 45)
	plt.yticks(tick_marks, classes)

	if normalize:
		cm = cm.astype('float') / cm.sum(axis= 1)[:, np.newaxis]
		print('Normalized Confusion Matrix')

	else:
		print('Confusion Matrix, Without Normalization')

	print(cm)

	thresh = cm.max() / 2.
	for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
		plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

	plt.tight_layout()
	plt.ylabel('True Label')
	plt.xlabel('Predicted Label')

# %% [markdown]
# # **Model Structure**

# %% [markdown]
# #### **Start Reading Dataset**

# %%
data_dir = ['/content/drive/MyDrive/C-NMC_Leukemia/training_data','/content/drive/MyDrive/C-NMC_Leukemia/validation_data']

try:
    # Get splitted data
    train_df, test_df = create_df(data_dir)

except:
    print('Invalid Input')

# %% [markdown]
# #### Define batch size, and steps, and image data Generator

# %%
# Recommended : use custom function for test data batch size, else we can use normal batch size.
batch_size = 40
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

# define model parameters
img_size = (224, 224)
channels = 3 # either BGR or Grayscale
color = 'rgb'
img_shape = (img_size[0], img_size[1], channels)

def scalar(img):
    return img

# train gen with data augnmentation, valid and test gen does not have augmentation
tr_gen = ImageDataGenerator(preprocessing_function= scalar)
ts_gen = ImageDataGenerator(preprocessing_function= scalar)

# Get Generators
train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= False, batch_size= batch_size)

test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= False, batch_size= batch_size)
# Out:
# Found 8035 validated image filenames belonging to 2 classes.
# Found 4522 validated image filenames belonging to 2 classes.

# %% [markdown]
# ###**Initialize Prediction array, Get Models and Weights**

# %%
#Initialize train_x, train_y, and arrays of models and predictions
base_model_predictions = []
models = []
train_y = train_df.labels
train_x = train_df.drop(['labels'],axis=1)

# create and compile pre-trained models

# Model 1
base_model = tf.keras.applications.ConvNeXtTiny(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
model1 = Sequential([
  base_model,
  BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
  Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
              bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
  Dropout(rate= 0.45, seed= 123),
  Dense(2, activation= 'softmax')
])
model1.compile(Adamax(learning_rate= 0.0012), loss= 'categorical_crossentropy', metrics= ['accuracy'])
model1.load_weights(f'/content/drive/MyDrive/Models/ALL-final-{model1_name}-weights.h5')
model1.summary()

# Model 2
base_model = tf.keras.applications.MobileNetV2(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
model2 = Sequential([
  base_model,
  BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
  Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
              bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
  Dropout(rate= 0.45, seed= 123),
  Dense(2, activation= 'softmax')
])
model2.compile(Adamax(learning_rate= 0.0012), loss= 'categorical_crossentropy', metrics= ['accuracy'])
model2.load_weights(f'/content/drive/MyDrive/Models/ALL-final-{model2_name}-weights.h5')
model2.summary()

# Model 3
base_model = tf.keras.applications.EfficientNetV2B3(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
model3 = Sequential([
  base_model,
  BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
  Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
              bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
  Dropout(rate= 0.45, seed= 123),
  Dense(2, activation= 'softmax')
])
model3.compile(Adamax(learning_rate= 0.0012), loss= 'categorical_crossentropy', metrics= ['accuracy'])
model3.load_weights(f'/content/drive/MyDrive/Models/ALL-final-{model3_name}-weights.h5')
model3.summary()

# Model 4
base_model = tf.keras.applications.DenseNet121(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
model4 = Sequential([
  base_model,
  BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
  Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
              bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
  Dropout(rate= 0.45, seed= 123),
  Dense(2, activation= 'softmax')
])
model4.compile(Adamax(learning_rate= 0.0012), loss= 'categorical_crossentropy', metrics= ['accuracy'])
model4.load_weights(f'/content/drive/MyDrive/Models/ALL-final-{model4_name}-weights.h5')
model4.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_tiny_notop.h5
# 111650432/111650432 [==============================] - 5s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  convnext_tiny (Functional)  (None, 768)               27820128
#
#  batch_normalization (BatchN  (None, 768)              3072
#  ormalization)
#
#  dense (Dense)               (None, 256)               196864
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 28,020,578
# Trainable params: 28,019,042
# Non-trainable params: 1,536
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 1280)             2257984
#  ional)
#
#  batch_normalization_1 (Batc  (None, 1280)             5120
#  hNormalization)
#
#  dense_2 (Dense)             (None, 256)               327936
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 2,591,554
# Trainable params: 2,554,882
# Non-trainable params: 36,672
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52606240/52606240 [==============================] - 3s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-b3 (Function  (None, 1536)             12930622
#  al)
#
#  batch_normalization_2 (Batc  (None, 1536)             6144
#  hNormalization)
#
#  dense_4 (Dense)             (None, 256)               393472
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 13,330,752
# Trainable params: 13,218,464
# Non-trainable params: 112,288
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_6 (Dense)             (None, 256)               262400
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 7,304,514
# Trainable params: 7,218,818
# Non-trainable params: 85,696
# _________________________________________________________________

# %% [markdown]
# # **Stacking Ensemble Creation**

# %% [markdown]
# ### **Collect predictions from the base models**

# %%
# Make predictions
base_model_predictions = []
for model in [model1, model2, model3, model4]:
    predictions = model.predict_generator(train_gen, verbose= 1)
    base_model_predictions.append(predictions[:, 0])  # Extract the probability for the 0 class (index 0)
# Out:
# 201/201 [==============================] - 3835s 19s/step
# 201/201 [==============================] - 52s 251ms/step
# 201/201 [==============================] - 58s 270ms/step
# 201/201 [==============================] - 57s 262ms/step

# %%
print(base_model_predictions)
# Out:
# [array([0.00232928, 0.00382692, 0.00371182, ..., 0.99801385, 0.9712228 ,
#        0.995695  ], dtype=float32), array([0.003234  , 0.00330884, 0.00420759, ..., 0.9934369 , 0.9625264 ,
#        0.995048  ], dtype=float32), array([0.00288614, 0.1375827 , 0.02690753, ..., 0.9909713 , 0.97919923,
#        0.98884135], dtype=float32), array([0.0095911 , 0.05420376, 0.00478132, ..., 0.97598785, 0.869274  ,
#        0.9666217 ], dtype=float32)]

# %% [markdown]
# ### **Preprocess the predictions as dataset for the meta model**

# %%
# Stack the base model predictions vertically
meta_input = np.vstack(base_model_predictions)

# Transpose the meta_input to match the input shape of the meta model
meta_input = meta_input.T

# Define the input size for the meta model
meta_input_size = meta_input.shape[1]

print(meta_input)
print()
print(len(meta_input))
print(meta_input_size)
# Out:
# [[0.00232928 0.003234   0.00288614 0.0095911 ]
#  [0.00382692 0.00330884 0.1375827  0.05420376]
#  [0.00371182 0.00420759 0.02690753 0.00478132]
#  ...
#  [0.99801385 0.9934369  0.9909713  0.97598785]
#  [0.9712228  0.9625264  0.97919923 0.869274  ]
#  [0.995695   0.995048   0.98884135 0.9666217 ]]
#
# 8035
# 4

# %% [markdown]
# ### **Meta model initialization**

# %%
# Define your meta model using Keras Sequential API with all layers defined within the parameters
meta_model = keras.models.Sequential(
    [
        keras.layers.Dense(units=64, activation='relu', input_shape=(meta_input_size,)),
        keras.layers.Dropout(0.15),  # Dropout layer for regularization
        keras.layers.Dense(units=32, activation='relu'),
        keras.layers.Dropout(0.15),  # Dropout layer for regularization
        keras.layers.Dense(units=1, activation='sigmoid')  # Output layer with sigmoid activation
    ]
)

meta_model.compile(loss='binary_crossentropy', optimizer='adamax', metrics=['accuracy'])

# %%
meta_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                320
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_10 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2,433
# Trainable params: 2,433
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Meta model training**

# %%
train_y_mapped = np.array(train_gen.classes)
meta_model.fit(x= meta_input,y= train_y_mapped, epochs=20, batch_size=32, verbose=1)
# Out:
# Epoch 1/20
# 252/252 [==============================] - 4s 5ms/step - loss: 0.2922 - accuracy: 0.8927
# Epoch 2/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1341 - accuracy: 0.9680
# Epoch 3/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1117 - accuracy: 0.9675
# Epoch 4/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1097 - accuracy: 0.9683
# Epoch 5/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1078 - accuracy: 0.9684
# Epoch 6/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1049 - accuracy: 0.9685
# Epoch 7/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1073 - accuracy: 0.9676
# Epoch 8/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1067 - accuracy: 0.9685
# Epoch 9/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1053 - accuracy: 0.9691
# Epoch 10/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1058 - accuracy: 0.9681
# Epoch 11/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1052 - accuracy: 0.9683
# Epoch 12/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1050 - accuracy: 0.9684
# Epoch 13/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1050 - accuracy: 0.9671
# Epoch 14/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1048 - accuracy: 0.9685
# Epoch 15/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1063 - accuracy: 0.9665
# Epoch 16/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1040 - accuracy: 0.9683
# Epoch 17/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1026 - accuracy: 0.9681
# Epoch 18/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1027 - accuracy: 0.9693
# Epoch 19/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1036 - accuracy: 0.9685
# Epoch 20/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.1046 - accuracy: 0.9689

# %% [markdown]
# # **Testing the stacking ensemble**

# %% [markdown]
# ### **Gather each base model's predictions on the test set**

# %%
# Make predictions on the validation set
base_model_predictions_val = []

# Storing metrics per model
acc_scores = []
pre_scores = []
w_pre_scores = []
rec_scores = []
w_rec_scores = []
f1_scores = []
w_f1_scores = []

for model in [model1, model2,model3,model4]:
    predictions_val = model.predict_generator(test_gen, verbose= 1)
    base_model_predictions_val.append(predictions_val[:, 0])  # Extract the probability for the 0 class (index 0)

    y_pred = np.argmax(predictions_val, axis=1)
    g_dict = test_gen.class_indices
    classes = list(g_dict.keys())

    # Confusion matrix (per model)
    cm = confusion_matrix(test_gen.classes, y_pred)
    plot_confusion_matrix(cm= cm, classes= classes, title = 'Confusion Matrix')

    # Classification report (per model)
    print(classification_report(test_gen.classes, y_pred, target_names= classes, digits= 4))

    # Append metrics
    acc_scores.append(accuracy_score(test_gen.classes, y_pred))
    pre_scores.append( precision_score(test_gen.classes, y_pred, pos_label= 0))
    w_pre_scores.append( precision_score(test_gen.classes, y_pred, average='weighted'))
    rec_scores.append(recall_score(test_gen.classes, y_pred, pos_label= 0))
    w_rec_scores.append(recall_score(test_gen.classes, y_pred, average='weighted'))
    f1_scores.append(f1_score(test_gen.classes, y_pred, pos_label= 0))
    w_f1_scores.append(f1_score(test_gen.classes, y_pred, average='weighted'))
# Out:
# 114/114 [==============================] - 2751s 24s/step
# Confusion Matrix, Without Normalization
# [[2998   43]
#  [ 188 1293]]
#               precision    recall  f1-score   support
#
#          all     0.9410    0.9859    0.9629      3041
#          hem     0.9678    0.8731    0.9180      1481
#
#     accuracy                         0.9489      4522
#    macro avg     0.9544    0.9295    0.9405      4522
# weighted avg     0.9498    0.9489    0.9482      4522
#
# 114/114 [==============================] - 28s 247ms/step
# Confusion Matrix, Without Normalization
# [[2936  105]
#  [ 228 1253]]
#               precision    recall  f1-score   support
#
#          all     0.9279    0.9655    0.9463      3041
#          hem     0.9227    0.8460    0.8827      1481
#
#     accuracy                         0.9264      4522
#    macro avg     0.9253    0.9058    0.9145      4522
# weighted avg     0.9262    0.9264    0.9255      4522
#
# 114/114 [==============================] - 28s 247ms/step
# Confusion Matrix, Without Normalization
# [[2857  184]
#  [ 246 1235]]
#               precision    recall  f1-score   support
#
#          all     0.9207    0.9395    0.9300      3041
#          hem     0.8703    0.8339    0.8517      1481
#
#     accuracy                         0.9049      4522
#    macro avg     0.8955    0.8867    0.8909      4522
# weighted avg     0.9042    0.9049    0.9044      4522
#
# 114/114 [==============================] - 29s 256ms/step
# Confusion Matrix, Without Normalization
# [[2949   92]
#  [ 329 1152]]
#               precision    recall  f1-score   support
#
#          all     0.8996    0.9697    0.9334      3041
#          hem     0.9260    0.7779    0.8455      1481
#
#     accuracy                         0.9069      4522
#    macro avg     0.9128    0.8738    0.8894      4522
# weighted avg     0.9083    0.9069    0.9046      4522

# %% [markdown]
# ### **Use the meta model to make the final predictions**

# %%
# Stack the base model predictions vertically
meta_input_val = np.vstack(base_model_predictions_val)

# Transpose the meta_input to match the input shape of the meta model
meta_input_val = meta_input_val.T

predictions_val_meta = meta_model.predict(meta_input_val)
# Out:
# 142/142 [==============================] - 0s 1ms/step

# %% [markdown]
# ### **Evaluate the stacking ensemble's final predictions**

# %%
# Convert the sigmoid predictions to class labels (0 or 1)
predicted_labels_val = (predictions_val_meta > 0.5).astype(int)

g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Confusion matrix
print('')
cm = confusion_matrix(test_gen.classes, predicted_labels_val)
plot_confusion_matrix(cm= cm, classes= classes, title = 'Confusion Matrix (Stacking Ensemble - Test Set)')

# Classification report
print('')
print(classification_report(test_gen.classes, predicted_labels_val, target_names= classes, digits= 4))
# Out:
# Confusion Matrix, Without Normalization
# [[3012   29]
#  [ 189 1292]]
#
#               precision    recall  f1-score   support
#
#          all     0.9410    0.9905    0.9651      3041
#          hem     0.9780    0.8724    0.9222      1481
#
#     accuracy                         0.9518      4522
#    macro avg     0.9595    0.9314    0.9436      4522
# weighted avg     0.9531    0.9518    0.9510      4522

# %% [markdown]
# # **Threshold adjustments**

# %%
y_pred_probs = np.copy(predictions_val_meta)

# experimenting thresholds
acc_list = []
pre_list = []
w_pre_list = []
rec_list = []
w_rec_list = []
f1_list = []
w_f1_list = []

threshold = 0.6

for x in range(101):
  threshold = round(0.6 - x*0.005, 3)
  y_pred_adjusted = (y_pred_probs >= threshold).astype(int) # Applying the adjusted thresholds for each class

  # Confusion matrix
  cm = confusion_matrix(test_gen.classes, y_pred_adjusted)
  print()
  print(f'Confusion Matrix - Thresholds: {round(1-threshold,3)}, {threshold}')
  print(cm)
  # Classification report
  print(classification_report(test_gen.classes, y_pred_adjusted, target_names= classes, digits= 4))
  print()

  acc_list.append(accuracy_score(test_gen.classes, y_pred_adjusted))
  pre_list.append( precision_score(test_gen.classes, y_pred_adjusted, pos_label= 0))
  w_pre_list.append( precision_score(test_gen.classes, y_pred_adjusted, average='weighted'))
  rec_list.append(recall_score(test_gen.classes, y_pred_adjusted, pos_label= 0))
  w_rec_list.append(recall_score(test_gen.classes, y_pred_adjusted, average='weighted'))
  f1_list.append(f1_score(test_gen.classes, y_pred_adjusted, pos_label= 0))
  w_f1_list.append(f1_score(test_gen.classes, y_pred_adjusted, average='weighted'))
# Out:
# Confusion Matrix - Thresholds: 0.4, 0.6
# [[3019   22]
#  [ 213 1268]]
#               precision    recall  f1-score   support
#
#          all     0.9341    0.9928    0.9625      3041
#          hem     0.9829    0.8562    0.9152      1481
#
#     accuracy                         0.9480      4522
#    macro avg     0.9585    0.9245    0.9389      4522
# weighted avg     0.9501    0.9480    0.9470      4522
#
#
#
# Confusion Matrix - Thresholds: 0.405, 0.595
# [[3019   22]
#  [ 213 1268]]
#               precision    recall  f1-score   support
#
#          all     0.9341    0.9928    0.9625      3041
#          hem     0.9829    0.8562    0.9152      1481
#
#     accuracy                         0.9480      4522
#    macro avg     0.9585    0.9245    0.9389      4522
# weighted avg     0.9501    0.9480    0.9470      4522
#
#
#
# Confusion Matrix - Thresholds: 0.41, 0.59
# [[3019   22]
#  [ 211 1270]]
#               precision    recall  f1-score   support
#
#          all     0.9347    0.9928    0.9628      3041
#          hem     0.9830    0.8575    0.9160      1481
#
#     accuracy                         0.9485      4522
#    macro avg     0.9588    0.9251    0.9394      4522
# weighted avg     0.9505    0.9485    0.9475      4522
#
#
#
# Confusion Matrix - Thresholds: 0.415, 0.585
# [[3019   22]
#  [ 210 1271]]
#               precision    recall  f1-score   support
#
#          all     0.9350    0.9928    0.9630      3041
#          hem     0.9830    0.8582    0.9164      1481
#
#     accuracy                         0.9487      4522
#    macro avg     0.9590    0.9255    0.9397      4522
# weighted avg     0.9507    0.9487    0.9477      4522
#
#
#
# Confusion Matrix - Thresholds: 0.42, 0.58
# [[3018   23]
#  [ 209 1272]]
#               precision    recall  f1-score   support
#
#          all     0.9352    0.9924    0.9630      3041
#          hem     0.9822    0.8589    0.9164      1481
#
#     accuracy                         0.9487      4522
#    macro avg     0.9587    0.9257    0.9397      4522
# weighted avg     0.9506    0.9487    0.9477      4522
#
#
#
# Confusion Matrix - Thresholds: 0.425, 0.575
# [[3018   23]
#  [ 209 1272]]
#               precision    recall  f1-score   support
#
#          all     0.9352    0.9924    0.9630      3041
#          hem     0.9822    0.8589    0.9164      1481
#
#     accuracy                         0.9487      4522
#    macro avg     0.9587    0.9257    0.9397      4522
# weighted avg     0.9506    0.9487    0.9477      4522
#
#
#
# Confusion Matrix - Thresholds: 0.43, 0.57
# [[3018   23]
#  [ 209 1272]]
#               precision    recall  f1-score   support
#
#          all     0.9352    0.9924    0.9630      3041
#          hem     0.9822    0.8589    0.9164      1481
#
#     accuracy                         0.9487      4522
#    macro avg     0.9587    0.9257    0.9397      4522
# weighted avg     0.9506    0.9487    0.9477      4522
#
#
#
# Confusion Matrix - Thresholds: 0.435, 0.565
# [[3018   23]
#  [ 209 1272]]
#               precision    recall  f1-score   support
#
#          all     0.9352    0.9924    0.9630      3041
#          hem     0.9822    0.8589    0.9164      1481
#
#     accuracy                         0.9487      4522
#    macro avg     0.9587    0.9257    0.9397      4522
# weighted avg     0.9506    0.9487    0.9477      4522
#
#
#
# Confusion Matrix - Thresholds: 0.44, 0.56
# [[3018   23]
#  [ 205 1276]]
#               precision    recall  f1-score   support
#
#          all     0.9364    0.9924    0.9636      3041
#          hem     0.9823    0.8616    0.9180      1481
#
#     accuracy                         0.9496      4522
#    macro avg     0.9593    0.9270    0.9408      4522
# weighted avg     0.9514    0.9496    0.9487      4522
#
#
#
# Confusion Matrix - Thresholds: 0.445, 0.555
# [[3018   23]
#  [ 203 1278]]
#               precision    recall  f1-score   support
#
#          all     0.9370    0.9924    0.9639      3041
#          hem     0.9823    0.8629    0.9188      1481
#
#     accuracy                         0.9500      4522
#    macro avg     0.9596    0.9277    0.9413      4522
# weighted avg     0.9518    0.9500    0.9491      4522
#
#
#
# Confusion Matrix - Thresholds: 0.45, 0.55
# [[3018   23]
#  [ 201 1280]]
#               precision    recall  f1-score   support
#
#          all     0.9376    0.9924    0.9642      3041
#          hem     0.9823    0.8643    0.9195      1481
#
#     accuracy                         0.9505      4522
#    macro avg     0.9600    0.9284    0.9419      4522
# weighted avg     0.9522    0.9505    0.9496      4522
#
#
#
# Confusion Matrix - Thresholds: 0.455, 0.545
# [[3017   24]
#  [ 201 1280]]
#               precision    recall  f1-score   support
#
#          all     0.9375    0.9921    0.9641      3041
#          hem     0.9816    0.8643    0.9192      1481
#
#     accuracy                         0.9502      4522
#    macro avg     0.9596    0.9282    0.9416      4522
# weighted avg     0.9520    0.9502    0.9494      4522
#
#
#
# Confusion Matrix - Thresholds: 0.46, 0.54
# [[3017   24]
#  [ 201 1280]]
#               precision    recall  f1-score   support
#
#          all     0.9375    0.9921    0.9641      3041
#          hem     0.9816    0.8643    0.9192      1481
#
#     accuracy                         0.9502      4522
#    macro avg     0.9596    0.9282    0.9416      4522
# weighted avg     0.9520    0.9502    0.9494      4522
#
#
#
# Confusion Matrix - Thresholds: 0.465, 0.535
# [[3017   24]
#  [ 199 1282]]
#               precision    recall  f1-score   support
#
#          all     0.9381    0.9921    0.9644      3041
#          hem     0.9816    0.8656    0.9200      1481
#
#     accuracy                         0.9507      4522
#    macro avg     0.9599    0.9289    0.9422      4522
# weighted avg     0.9524    0.9507    0.9498      4522
#
#
#
# Confusion Matrix - Thresholds: 0.47, 0.53
# [[3016   25]
#  [ 198 1283]]
#               precision    recall  f1-score   support
#
#          all     0.9384    0.9918    0.9643      3041
#          hem     0.9809    0.8663    0.9200      1481
#
#     accuracy                         0.9507      4522
#    macro avg     0.9596    0.9290    0.9422      4522
# weighted avg     0.9523    0.9507    0.9498      4522
#
#
#
# Confusion Matrix - Thresholds: 0.475, 0.525
# [[3016   25]
#  [ 195 1286]]
#               precision    recall  f1-score   support
#
#          all     0.9393    0.9918    0.9648      3041
#          hem     0.9809    0.8683    0.9212      1481
#
#     accuracy                         0.9513      4522
#    macro avg     0.9601    0.9301    0.9430      4522
# weighted avg     0.9529    0.9513    0.9505      4522
#
#
#
# Confusion Matrix - Thresholds: 0.48, 0.52
# [[3015   26]
#  [ 193 1288]]
#               precision    recall  f1-score   support
#
#          all     0.9398    0.9915    0.9650      3041
#          hem     0.9802    0.8697    0.9216      1481
#
#     accuracy                         0.9516      4522
#    macro avg     0.9600    0.9306    0.9433      4522
# weighted avg     0.9531    0.9516    0.9508      4522
#
#
#
# Confusion Matrix - Thresholds: 0.485, 0.515
# [[3015   26]
#  [ 193 1288]]
#               precision    recall  f1-score   support
#
#          all     0.9398    0.9915    0.9650      3041
#          hem     0.9802    0.8697    0.9216      1481
#
#     accuracy                         0.9516      4522
#    macro avg     0.9600    0.9306    0.9433      4522
# weighted avg     0.9531    0.9516    0.9508      4522
#
#
#
# Confusion Matrix - Thresholds: 0.49, 0.51
# [[3015   26]
#  [ 191 1290]]
#               precision    recall  f1-score   support
#
#          all     0.9404    0.9915    0.9653      3041
#          hem     0.9802    0.8710    0.9224      1481
#
#     accuracy                         0.9520      4522
#    macro avg     0.9603    0.9312    0.9438      4522
# weighted avg     0.9535    0.9520    0.9512      4522
#
#
#
# Confusion Matrix - Thresholds: 0.495, 0.505
# [[3014   27]
#  [ 191 1290]]
#               precision    recall  f1-score   support
#
#          all     0.9404    0.9911    0.9651      3041
#          hem     0.9795    0.8710    0.9221      1481
#
#     accuracy                         0.9518      4522
#    macro avg     0.9600    0.9311    0.9436      4522
# weighted avg     0.9532    0.9518    0.9510      4522
#
#
#
# Confusion Matrix - Thresholds: 0.5, 0.5
# [[3012   29]
#  [ 189 1292]]
#               precision    recall  f1-score   support
#
#          all     0.9410    0.9905    0.9651      3041
#          hem     0.9780    0.8724    0.9222      1481
#
#     accuracy                         0.9518      4522
#    macro avg     0.9595    0.9314    0.9436      4522
# weighted avg     0.9531    0.9518    0.9510      4522
#
#
#
# Confusion Matrix - Thresholds: 0.505, 0.495
# [[3012   29]
#  [ 189 1292]]
#               precision    recall  f1-score   support
#
#          all     0.9410    0.9905    0.9651      3041
#          hem     0.9780    0.8724    0.9222      1481
#
#     accuracy                         0.9518      4522
#    macro avg     0.9595    0.9314    0.9436      4522
# weighted avg     0.9531    0.9518    0.9510      4522
#
#
#
# Confusion Matrix - Thresholds: 0.51, 0.49
# [[3011   30]
#  [ 187 1294]]
#               precision    recall  f1-score   support
#
#          all     0.9415    0.9901    0.9652      3041
#          hem     0.9773    0.8737    0.9226      1481
#
#     accuracy                         0.9520      4522
#    macro avg     0.9594    0.9319    0.9439      4522
# weighted avg     0.9533    0.9520    0.9513      4522
#
#
#
# Confusion Matrix - Thresholds: 0.515, 0.485
# [[3011   30]
#  [ 185 1296]]
#               precision    recall  f1-score   support
#
#          all     0.9421    0.9901    0.9655      3041
#          hem     0.9774    0.8751    0.9234      1481
#
#     accuracy                         0.9525      4522
#    macro avg     0.9597    0.9326    0.9445      4522
# weighted avg     0.9537    0.9525    0.9517      4522
#
#
#
# Confusion Matrix - Thresholds: 0.52, 0.48
# [[3011   30]
#  [ 185 1296]]
#               precision    recall  f1-score   support
#
#          all     0.9421    0.9901    0.9655      3041
#          hem     0.9774    0.8751    0.9234      1481
#
#     accuracy                         0.9525      4522
#    macro avg     0.9597    0.9326    0.9445      4522
# weighted avg     0.9537    0.9525    0.9517      4522
#
#
#
# Confusion Matrix - Thresholds: 0.525, 0.475
# [[3011   30]
#  [ 185 1296]]
#               precision    recall  f1-score   support
#
#          all     0.9421    0.9901    0.9655      3041
#          hem     0.9774    0.8751    0.9234      1481
#
#     accuracy                         0.9525      4522
#    macro avg     0.9597    0.9326    0.9445      4522
# weighted avg     0.9537    0.9525    0.9517      4522
#
#
#
# Confusion Matrix - Thresholds: 0.53, 0.47
# [[3011   30]
#  [ 184 1297]]
#               precision    recall  f1-score   support
#
#          all     0.9424    0.9901    0.9657      3041
#          hem     0.9774    0.8758    0.9238      1481
#
#     accuracy                         0.9527      4522
#    macro avg     0.9599    0.9329    0.9447      4522
# weighted avg     0.9539    0.9527    0.9520      4522
#
#
#
# Confusion Matrix - Thresholds: 0.535, 0.465
# [[3009   32]
#  [ 182 1299]]
#               precision    recall  f1-score   support
#
#          all     0.9430    0.9895    0.9657      3041
#          hem     0.9760    0.8771    0.9239      1481
#
#     accuracy                         0.9527      4522
#    macro avg     0.9595    0.9333    0.9448      4522
# weighted avg     0.9538    0.9527    0.9520      4522
#
#
#
# Confusion Matrix - Thresholds: 0.54, 0.46
# [[3009   32]
#  [ 182 1299]]
#               precision    recall  f1-score   support
#
#          all     0.9430    0.9895    0.9657      3041
#          hem     0.9760    0.8771    0.9239      1481
#
#     accuracy                         0.9527      4522
#    macro avg     0.9595    0.9333    0.9448      4522
# weighted avg     0.9538    0.9527    0.9520      4522
#
#
#
# Confusion Matrix - Thresholds: 0.545, 0.455
# [[3009   32]
#  [ 182 1299]]
#               precision    recall  f1-score   support
#
#          all     0.9430    0.9895    0.9657      3041
#          hem     0.9760    0.8771    0.9239      1481
#
#     accuracy                         0.9527      4522
#    macro avg     0.9595    0.9333    0.9448      4522
# weighted avg     0.9538    0.9527    0.9520      4522
#
#
#
# Confusion Matrix - Thresholds: 0.55, 0.45
# [[3009   32]
#  [ 181 1300]]
#               precision    recall  f1-score   support
#
#          all     0.9433    0.9895    0.9658      3041
#          hem     0.9760    0.8778    0.9243      1481
#
#     accuracy                         0.9529      4522
#    macro avg     0.9596    0.9336    0.9450      4522
# weighted avg     0.9540    0.9529    0.9522      4522
#
#
#
# Confusion Matrix - Thresholds: 0.555, 0.445
# [[3009   32]
#  [ 179 1302]]
#               precision    recall  f1-score   support
#
#          all     0.9439    0.9895    0.9661      3041
#          hem     0.9760    0.8791    0.9250      1481
#
#     accuracy                         0.9533      4522
#    macro avg     0.9599    0.9343    0.9456      4522
# weighted avg     0.9544    0.9533    0.9527      4522
#
#
#
# Confusion Matrix - Thresholds: 0.56, 0.44
# [[3008   33]
#  [ 178 1303]]
#               precision    recall  f1-score   support
#
#          all     0.9441    0.9891    0.9661      3041
#          hem     0.9753    0.8798    0.9251      1481
#
#     accuracy                         0.9533      4522
#    macro avg     0.9597    0.9345    0.9456      4522
# weighted avg     0.9543    0.9533    0.9527      4522
#
#
#
# Confusion Matrix - Thresholds: 0.565, 0.435
# [[3007   34]
#  [ 178 1303]]
#               precision    recall  f1-score   support
#
#          all     0.9441    0.9888    0.9659      3041
#          hem     0.9746    0.8798    0.9248      1481
#
#     accuracy                         0.9531      4522
#    macro avg     0.9593    0.9343    0.9454      4522
# weighted avg     0.9541    0.9531    0.9525      4522
#
#
#
# Confusion Matrix - Thresholds: 0.57, 0.43
# [[3007   34]
#  [ 177 1304]]
#               precision    recall  f1-score   support
#
#          all     0.9444    0.9888    0.9661      3041
#          hem     0.9746    0.8805    0.9252      1481
#
#     accuracy                         0.9533      4522
#    macro avg     0.9595    0.9347    0.9456      4522
# weighted avg     0.9543    0.9533    0.9527      4522
#
#
#
# Confusion Matrix - Thresholds: 0.575, 0.425
# [[3007   34]
#  [ 175 1306]]
#               precision    recall  f1-score   support
#
#          all     0.9450    0.9888    0.9664      3041
#          hem     0.9746    0.8818    0.9259      1481
#
#     accuracy                         0.9538      4522
#    macro avg     0.9598    0.9353    0.9462      4522
# weighted avg     0.9547    0.9538    0.9532      4522
#
#
#
# Confusion Matrix - Thresholds: 0.58, 0.42
# [[3007   34]
#  [ 174 1307]]
#               precision    recall  f1-score   support
#
#          all     0.9453    0.9888    0.9666      3041
#          hem     0.9746    0.8825    0.9263      1481
#
#     accuracy                         0.9540      4522
#    macro avg     0.9600    0.9357    0.9464      4522
# weighted avg     0.9549    0.9540    0.9534      4522
#
#
#
# Confusion Matrix - Thresholds: 0.585, 0.415
# [[3006   35]
#  [ 173 1308]]
#               precision    recall  f1-score   support
#
#          all     0.9456    0.9885    0.9666      3041
#          hem     0.9739    0.8832    0.9263      1481
#
#     accuracy                         0.9540      4522
#    macro avg     0.9598    0.9358    0.9465      4522
# weighted avg     0.9549    0.9540    0.9534      4522
#
#
#
# Confusion Matrix - Thresholds: 0.59, 0.41
# [[3006   35]
#  [ 173 1308]]
#               precision    recall  f1-score   support
#
#          all     0.9456    0.9885    0.9666      3041
#          hem     0.9739    0.8832    0.9263      1481
#
#     accuracy                         0.9540      4522
#    macro avg     0.9598    0.9358    0.9465      4522
# weighted avg     0.9549    0.9540    0.9534      4522
#
#
#
# Confusion Matrix - Thresholds: 0.595, 0.405
# [[3006   35]
#  [ 172 1309]]
#               precision    recall  f1-score   support
#
#          all     0.9459    0.9885    0.9667      3041
#          hem     0.9740    0.8839    0.9267      1481
#
#     accuracy                         0.9542      4522
#    macro avg     0.9599    0.9362    0.9467      4522
# weighted avg     0.9551    0.9542    0.9536      4522
#
#
#
# Confusion Matrix - Thresholds: 0.6, 0.4
# [[3006   35]
#  [ 168 1313]]
#               precision    recall  f1-score   support
#
#          all     0.9471    0.9885    0.9673      3041
#          hem     0.9740    0.8866    0.9282      1481
#
#     accuracy                         0.9551      4522
#    macro avg     0.9606    0.9375    0.9478      4522
# weighted avg     0.9559    0.9551    0.9545      4522
#
#
#
# Confusion Matrix - Thresholds: 0.605, 0.395
# [[3005   36]
#  [ 167 1314]]
#               precision    recall  f1-score   support
#
#          all     0.9474    0.9882    0.9673      3041
#          hem     0.9733    0.8872    0.9283      1481
#
#     accuracy                         0.9551      4522
#    macro avg     0.9603    0.9377    0.9478      4522
# weighted avg     0.9559    0.9551    0.9545      4522
#
#
#
# Confusion Matrix - Thresholds: 0.61, 0.39
# [[3005   36]
#  [ 166 1315]]
#               precision    recall  f1-score   support
#
#          all     0.9477    0.9882    0.9675      3041
#          hem     0.9734    0.8879    0.9287      1481
#
#     accuracy                         0.9553      4522
#    macro avg     0.9605    0.9380    0.9481      4522
# weighted avg     0.9561    0.9553    0.9548      4522
#
#
#
# Confusion Matrix - Thresholds: 0.615, 0.385
# [[3005   36]
#  [ 164 1317]]
#               precision    recall  f1-score   support
#
#          all     0.9482    0.9882    0.9678      3041
#          hem     0.9734    0.8893    0.9294      1481
#
#     accuracy                         0.9558      4522
#    macro avg     0.9608    0.9387    0.9486      4522
# weighted avg     0.9565    0.9558    0.9552      4522
#
#
#
# Confusion Matrix - Thresholds: 0.62, 0.38
# [[3005   36]
#  [ 164 1317]]
#               precision    recall  f1-score   support
#
#          all     0.9482    0.9882    0.9678      3041
#          hem     0.9734    0.8893    0.9294      1481
#
#     accuracy                         0.9558      4522
#    macro avg     0.9608    0.9387    0.9486      4522
# weighted avg     0.9565    0.9558    0.9552      4522
#
#
#
# Confusion Matrix - Thresholds: 0.625, 0.375
# [[3005   36]
#  [ 163 1318]]
#               precision    recall  f1-score   support
#
#          all     0.9485    0.9882    0.9679      3041
#          hem     0.9734    0.8899    0.9298      1481
#
#     accuracy                         0.9560      4522
#    macro avg     0.9610    0.9391    0.9489      4522
# weighted avg     0.9567    0.9560    0.9555      4522
#
#
#
# Confusion Matrix - Thresholds: 0.63, 0.37
# [[3004   37]
#  [ 163 1318]]
#               precision    recall  f1-score   support
#
#          all     0.9485    0.9878    0.9678      3041
#          hem     0.9727    0.8899    0.9295      1481
#
#     accuracy                         0.9558      4522
#    macro avg     0.9606    0.9389    0.9486      4522
# weighted avg     0.9564    0.9558    0.9552      4522
#
#
#
# Confusion Matrix - Thresholds: 0.635, 0.365
# [[3004   37]
#  [ 163 1318]]
#               precision    recall  f1-score   support
#
#          all     0.9485    0.9878    0.9678      3041
#          hem     0.9727    0.8899    0.9295      1481
#
#     accuracy                         0.9558      4522
#    macro avg     0.9606    0.9389    0.9486      4522
# weighted avg     0.9564    0.9558    0.9552      4522
#
#
#
# Confusion Matrix - Thresholds: 0.64, 0.36
# [[3004   37]
#  [ 161 1320]]
#               precision    recall  f1-score   support
#
#          all     0.9491    0.9878    0.9681      3041
#          hem     0.9727    0.8913    0.9302      1481
#
#     accuracy                         0.9562      4522
#    macro avg     0.9609    0.9396    0.9492      4522
# weighted avg     0.9569    0.9562    0.9557      4522
#
#
#
# Confusion Matrix - Thresholds: 0.645, 0.355
# [[3004   37]
#  [ 161 1320]]
#               precision    recall  f1-score   support
#
#          all     0.9491    0.9878    0.9681      3041
#          hem     0.9727    0.8913    0.9302      1481
#
#     accuracy                         0.9562      4522
#    macro avg     0.9609    0.9396    0.9492      4522
# weighted avg     0.9569    0.9562    0.9557      4522
#
#
#
# Confusion Matrix - Thresholds: 0.65, 0.35
# [[3004   37]
#  [ 160 1321]]
#               precision    recall  f1-score   support
#
#          all     0.9494    0.9878    0.9683      3041
#          hem     0.9728    0.8920    0.9306      1481
#
#     accuracy                         0.9564      4522
#    macro avg     0.9611    0.9399    0.9494      4522
# weighted avg     0.9571    0.9564    0.9559      4522
#
#
#
# Confusion Matrix - Thresholds: 0.655, 0.345
# [[3004   37]
#  [ 160 1321]]
#               precision    recall  f1-score   support
#
#          all     0.9494    0.9878    0.9683      3041
#          hem     0.9728    0.8920    0.9306      1481
#
#     accuracy                         0.9564      4522
#    macro avg     0.9611    0.9399    0.9494      4522
# weighted avg     0.9571    0.9564    0.9559      4522
#
#
#
# Confusion Matrix - Thresholds: 0.66, 0.34
# [[3004   37]
#  [ 157 1324]]
#               precision    recall  f1-score   support
#
#          all     0.9503    0.9878    0.9687      3041
#          hem     0.9728    0.8940    0.9317      1481
#
#     accuracy                         0.9571      4522
#    macro avg     0.9616    0.9409    0.9502      4522
# weighted avg     0.9577    0.9571    0.9566      4522
#
#
#
# Confusion Matrix - Thresholds: 0.665, 0.335
# [[3004   37]
#  [ 156 1325]]
#               precision    recall  f1-score   support
#
#          all     0.9506    0.9878    0.9689      3041
#          hem     0.9728    0.8947    0.9321      1481
#
#     accuracy                         0.9573      4522
#    macro avg     0.9617    0.9412    0.9505      4522
# weighted avg     0.9579    0.9573    0.9568      4522
#
#
#
# Confusion Matrix - Thresholds: 0.67, 0.33
# [[3004   37]
#  [ 156 1325]]
#               precision    recall  f1-score   support
#
#          all     0.9506    0.9878    0.9689      3041
#          hem     0.9728    0.8947    0.9321      1481
#
#     accuracy                         0.9573      4522
#    macro avg     0.9617    0.9412    0.9505      4522
# weighted avg     0.9579    0.9573    0.9568      4522
#
#
#
# Confusion Matrix - Thresholds: 0.675, 0.325
# [[3004   37]
#  [ 156 1325]]
#               precision    recall  f1-score   support
#
#          all     0.9506    0.9878    0.9689      3041
#          hem     0.9728    0.8947    0.9321      1481
#
#     accuracy                         0.9573      4522
#    macro avg     0.9617    0.9412    0.9505      4522
# weighted avg     0.9579    0.9573    0.9568      4522
#
#
#
# Confusion Matrix - Thresholds: 0.68, 0.32
# [[3004   37]
#  [ 155 1326]]
#               precision    recall  f1-score   support
#
#          all     0.9509    0.9878    0.9690      3041
#          hem     0.9729    0.8953    0.9325      1481
#
#     accuracy                         0.9575      4522
#    macro avg     0.9619    0.9416    0.9508      4522
# weighted avg     0.9581    0.9575    0.9571      4522
#
#
#
# Confusion Matrix - Thresholds: 0.685, 0.315
# [[3003   38]
#  [ 155 1326]]
#               precision    recall  f1-score   support
#
#          all     0.9509    0.9875    0.9689      3041
#          hem     0.9721    0.8953    0.9322      1481
#
#     accuracy                         0.9573      4522
#    macro avg     0.9615    0.9414    0.9505      4522
# weighted avg     0.9579    0.9573    0.9568      4522
#
#
#
# Confusion Matrix - Thresholds: 0.69, 0.31
# [[3003   38]
#  [ 150 1331]]
#               precision    recall  f1-score   support
#
#          all     0.9524    0.9875    0.9696      3041
#          hem     0.9722    0.8987    0.9340      1481
#
#     accuracy                         0.9584      4522
#    macro avg     0.9623    0.9431    0.9518      4522
# weighted avg     0.9589    0.9584    0.9580      4522
#
#
#
# Confusion Matrix - Thresholds: 0.695, 0.305
# [[3003   38]
#  [ 150 1331]]
#               precision    recall  f1-score   support
#
#          all     0.9524    0.9875    0.9696      3041
#          hem     0.9722    0.8987    0.9340      1481
#
#     accuracy                         0.9584      4522
#    macro avg     0.9623    0.9431    0.9518      4522
# weighted avg     0.9589    0.9584    0.9580      4522
#
#
#
# Confusion Matrix - Thresholds: 0.7, 0.3
# [[3001   40]
#  [ 150 1331]]
#               precision    recall  f1-score   support
#
#          all     0.9524    0.9868    0.9693      3041
#          hem     0.9708    0.8987    0.9334      1481
#
#     accuracy                         0.9580      4522
#    macro avg     0.9616    0.9428    0.9513      4522
# weighted avg     0.9584    0.9580    0.9575      4522
#
#
#
# Confusion Matrix - Thresholds: 0.705, 0.295
# [[3001   40]
#  [ 149 1332]]
#               precision    recall  f1-score   support
#
#          all     0.9527    0.9868    0.9695      3041
#          hem     0.9708    0.8994    0.9338      1481
#
#     accuracy                         0.9582      4522
#    macro avg     0.9618    0.9431    0.9516      4522
# weighted avg     0.9586    0.9582    0.9578      4522
#
#
#
# Confusion Matrix - Thresholds: 0.71, 0.29
# [[3000   41]
#  [ 147 1334]]
#               precision    recall  f1-score   support
#
#          all     0.9533    0.9865    0.9696      3041
#          hem     0.9702    0.9007    0.9342      1481
#
#     accuracy                         0.9584      4522
#    macro avg     0.9617    0.9436    0.9519      4522
# weighted avg     0.9588    0.9584    0.9580      4522
#
#
#
# Confusion Matrix - Thresholds: 0.715, 0.285
# [[2998   43]
#  [ 147 1334]]
#               precision    recall  f1-score   support
#
#          all     0.9533    0.9859    0.9693      3041
#          hem     0.9688    0.9007    0.9335      1481
#
#     accuracy                         0.9580      4522
#    macro avg     0.9610    0.9433    0.9514      4522
# weighted avg     0.9583    0.9580    0.9576      4522
#
#
#
# Confusion Matrix - Thresholds: 0.72, 0.28
# [[2998   43]
#  [ 147 1334]]
#               precision    recall  f1-score   support
#
#          all     0.9533    0.9859    0.9693      3041
#          hem     0.9688    0.9007    0.9335      1481
#
#     accuracy                         0.9580      4522
#    macro avg     0.9610    0.9433    0.9514      4522
# weighted avg     0.9583    0.9580    0.9576      4522
#
#
#
# Confusion Matrix - Thresholds: 0.725, 0.275
# [[2997   44]
#  [ 147 1334]]
#               precision    recall  f1-score   support
#
#          all     0.9532    0.9855    0.9691      3041
#          hem     0.9681    0.9007    0.9332      1481
#
#     accuracy                         0.9578      4522
#    macro avg     0.9607    0.9431    0.9512      4522
# weighted avg     0.9581    0.9578    0.9574      4522
#
#
#
# Confusion Matrix - Thresholds: 0.73, 0.27
# [[2995   46]
#  [ 147 1334]]
#               precision    recall  f1-score   support
#
#          all     0.9532    0.9849    0.9688      3041
#          hem     0.9667    0.9007    0.9325      1481
#
#     accuracy                         0.9573      4522
#    macro avg     0.9599    0.9428    0.9507      4522
# weighted avg     0.9576    0.9573    0.9569      4522
#
#
#
# Confusion Matrix - Thresholds: 0.735, 0.265
# [[2995   46]
#  [ 146 1335]]
#               precision    recall  f1-score   support
#
#          all     0.9535    0.9849    0.9689      3041
#          hem     0.9667    0.9014    0.9329      1481
#
#     accuracy                         0.9575      4522
#    macro avg     0.9601    0.9431    0.9509      4522
# weighted avg     0.9578    0.9575    0.9571      4522
#
#
#
# Confusion Matrix - Thresholds: 0.74, 0.26
# [[2993   48]
#  [ 144 1337]]
#               precision    recall  f1-score   support
#
#          all     0.9541    0.9842    0.9689      3041
#          hem     0.9653    0.9028    0.9330      1481
#
#     accuracy                         0.9575      4522
#    macro avg     0.9597    0.9435    0.9510      4522
# weighted avg     0.9578    0.9575    0.9572      4522
#
#
#
# Confusion Matrix - Thresholds: 0.745, 0.255
# [[2991   50]
#  [ 143 1338]]
#               precision    recall  f1-score   support
#
#          all     0.9544    0.9836    0.9687      3041
#          hem     0.9640    0.9034    0.9327      1481
#
#     accuracy                         0.9573      4522
#    macro avg     0.9592    0.9435    0.9507      4522
# weighted avg     0.9575    0.9573    0.9569      4522
#
#
#
# Confusion Matrix - Thresholds: 0.75, 0.25
# [[2991   50]
#  [ 143 1338]]
#               precision    recall  f1-score   support
#
#          all     0.9544    0.9836    0.9687      3041
#          hem     0.9640    0.9034    0.9327      1481
#
#     accuracy                         0.9573      4522
#    macro avg     0.9592    0.9435    0.9507      4522
# weighted avg     0.9575    0.9573    0.9569      4522
#
#
#
# Confusion Matrix - Thresholds: 0.755, 0.245
# [[2989   52]
#  [ 143 1338]]
#               precision    recall  f1-score   support
#
#          all     0.9543    0.9829    0.9684      3041
#          hem     0.9626    0.9034    0.9321      1481
#
#     accuracy                         0.9569      4522
#    macro avg     0.9585    0.9432    0.9502      4522
# weighted avg     0.9570    0.9569    0.9565      4522
#
#
#
# Confusion Matrix - Thresholds: 0.76, 0.24
# [[2984   57]
#  [ 141 1340]]
#               precision    recall  f1-score   support
#
#          all     0.9549    0.9813    0.9679      3041
#          hem     0.9592    0.9048    0.9312      1481
#
#     accuracy                         0.9562      4522
#    macro avg     0.9570    0.9430    0.9495      4522
# weighted avg     0.9563    0.9562    0.9559      4522
#
#
#
# Confusion Matrix - Thresholds: 0.765, 0.235
# [[2982   59]
#  [ 141 1340]]
#               precision    recall  f1-score   support
#
#          all     0.9549    0.9806    0.9676      3041
#          hem     0.9578    0.9048    0.9306      1481
#
#     accuracy                         0.9558      4522
#    macro avg     0.9563    0.9427    0.9491      4522
# weighted avg     0.9558    0.9558    0.9554      4522
#
#
#
# Confusion Matrix - Thresholds: 0.77, 0.23
# [[2981   60]
#  [ 137 1344]]
#               precision    recall  f1-score   support
#
#          all     0.9561    0.9803    0.9680      3041
#          hem     0.9573    0.9075    0.9317      1481
#
#     accuracy                         0.9564      4522
#    macro avg     0.9567    0.9439    0.9499      4522
# weighted avg     0.9565    0.9564    0.9561      4522
#
#
#
# Confusion Matrix - Thresholds: 0.775, 0.225
# [[2974   67]
#  [ 136 1345]]
#               precision    recall  f1-score   support
#
#          all     0.9563    0.9780    0.9670      3041
#          hem     0.9525    0.9082    0.9298      1481
#
#     accuracy                         0.9551      4522
#    macro avg     0.9544    0.9431    0.9484      4522
# weighted avg     0.9551    0.9551    0.9548      4522
#
#
#
# Confusion Matrix - Thresholds: 0.78, 0.22
# [[2971   70]
#  [ 136 1345]]
#               precision    recall  f1-score   support
#
#          all     0.9562    0.9770    0.9665      3041
#          hem     0.9505    0.9082    0.9289      1481
#
#     accuracy                         0.9544      4522
#    macro avg     0.9534    0.9426    0.9477      4522
# weighted avg     0.9544    0.9544    0.9542      4522
#
#
#
# Confusion Matrix - Thresholds: 0.785, 0.215
# [[2970   71]
#  [ 134 1347]]
#               precision    recall  f1-score   support
#
#          all     0.9568    0.9767    0.9666      3041
#          hem     0.9499    0.9095    0.9293      1481
#
#     accuracy                         0.9547      4522
#    macro avg     0.9534    0.9431    0.9480      4522
# weighted avg     0.9546    0.9547    0.9544      4522
#
#
#
# Confusion Matrix - Thresholds: 0.79, 0.21
# [[2968   73]
#  [ 133 1348]]
#               precision    recall  f1-score   support
#
#          all     0.9571    0.9760    0.9665      3041
#          hem     0.9486    0.9102    0.9290      1481
#
#     accuracy                         0.9544      4522
#    macro avg     0.9529    0.9431    0.9477      4522
# weighted avg     0.9543    0.9544    0.9542      4522
#
#
#
# Confusion Matrix - Thresholds: 0.795, 0.205
# [[2966   75]
#  [ 133 1348]]
#               precision    recall  f1-score   support
#
#          all     0.9571    0.9753    0.9661      3041
#          hem     0.9473    0.9102    0.9284      1481
#
#     accuracy                         0.9540      4522
#    macro avg     0.9522    0.9428    0.9472      4522
# weighted avg     0.9539    0.9540    0.9538      4522
#
#
#
# Confusion Matrix - Thresholds: 0.8, 0.2
# [[2963   78]
#  [ 133 1348]]
#               precision    recall  f1-score   support
#
#          all     0.9570    0.9744    0.9656      3041
#          hem     0.9453    0.9102    0.9274      1481
#
#     accuracy                         0.9533      4522
#    macro avg     0.9512    0.9423    0.9465      4522
# weighted avg     0.9532    0.9533    0.9531      4522
#
#
#
# Confusion Matrix - Thresholds: 0.805, 0.195
# [[2956   85]
#  [ 131 1350]]
#               precision    recall  f1-score   support
#
#          all     0.9576    0.9720    0.9648      3041
#          hem     0.9408    0.9115    0.9259      1481
#
#     accuracy                         0.9522      4522
#    macro avg     0.9492    0.9418    0.9453      4522
# weighted avg     0.9521    0.9522    0.9520      4522
#
#
#
# Confusion Matrix - Thresholds: 0.81, 0.19
# [[2954   87]
#  [ 130 1351]]
#               precision    recall  f1-score   support
#
#          all     0.9578    0.9714    0.9646      3041
#          hem     0.9395    0.9122    0.9257      1481
#
#     accuracy                         0.9520      4522
#    macro avg     0.9487    0.9418    0.9451      4522
# weighted avg     0.9518    0.9520    0.9518      4522
#
#
#
# Confusion Matrix - Thresholds: 0.815, 0.185
# [[2953   88]
#  [ 129 1352]]
#               precision    recall  f1-score   support
#
#          all     0.9581    0.9711    0.9646      3041
#          hem     0.9389    0.9129    0.9257      1481
#
#     accuracy                         0.9520      4522
#    macro avg     0.9485    0.9420    0.9451      4522
# weighted avg     0.9518    0.9520    0.9518      4522
#
#
#
# Confusion Matrix - Thresholds: 0.82, 0.18
# [[2951   90]
#  [ 129 1352]]
#               precision    recall  f1-score   support
#
#          all     0.9581    0.9704    0.9642      3041
#          hem     0.9376    0.9129    0.9251      1481
#
#     accuracy                         0.9516      4522
#    macro avg     0.9479    0.9417    0.9446      4522
# weighted avg     0.9514    0.9516    0.9514      4522
#
#
#
# Confusion Matrix - Thresholds: 0.825, 0.175
# [[2947   94]
#  [ 127 1354]]
#               precision    recall  f1-score   support
#
#          all     0.9587    0.9691    0.9639      3041
#          hem     0.9351    0.9142    0.9245      1481
#
#     accuracy                         0.9511      4522
#    macro avg     0.9469    0.9417    0.9442      4522
# weighted avg     0.9510    0.9511    0.9510      4522
#
#
#
# Confusion Matrix - Thresholds: 0.83, 0.17
# [[2944   97]
#  [ 126 1355]]
#               precision    recall  f1-score   support
#
#          all     0.9590    0.9681    0.9635      3041
#          hem     0.9332    0.9149    0.9240      1481
#
#     accuracy                         0.9507      4522
#    macro avg     0.9461    0.9415    0.9437      4522
# weighted avg     0.9505    0.9507    0.9506      4522
#
#
#
# Confusion Matrix - Thresholds: 0.835, 0.165
# [[2943   98]
#  [ 126 1355]]
#               precision    recall  f1-score   support
#
#          all     0.9589    0.9678    0.9633      3041
#          hem     0.9326    0.9149    0.9237      1481
#
#     accuracy                         0.9505      4522
#    macro avg     0.9457    0.9413    0.9435      4522
# weighted avg     0.9503    0.9505    0.9503      4522
#
#
#
# Confusion Matrix - Thresholds: 0.84, 0.16
# [[2937  104]
#  [ 125 1356]]
#               precision    recall  f1-score   support
#
#          all     0.9592    0.9658    0.9625      3041
#          hem     0.9288    0.9156    0.9221      1481
#
#     accuracy                         0.9494      4522
#    macro avg     0.9440    0.9407    0.9423      4522
# weighted avg     0.9492    0.9494    0.9493      4522
#
#
#
# Confusion Matrix - Thresholds: 0.845, 0.155
# [[2935  106]
#  [ 123 1358]]
#               precision    recall  f1-score   support
#
#          all     0.9598    0.9651    0.9625      3041
#          hem     0.9276    0.9169    0.9222      1481
#
#     accuracy                         0.9494      4522
#    macro avg     0.9437    0.9410    0.9423      4522
# weighted avg     0.9492    0.9494    0.9493      4522
#
#
#
# Confusion Matrix - Thresholds: 0.85, 0.15
# [[2927  114]
#  [ 123 1358]]
#               precision    recall  f1-score   support
#
#          all     0.9597    0.9625    0.9611      3041
#          hem     0.9226    0.9169    0.9197      1481
#
#     accuracy                         0.9476      4522
#    macro avg     0.9411    0.9397    0.9404      4522
# weighted avg     0.9475    0.9476    0.9475      4522
#
#
#
# Confusion Matrix - Thresholds: 0.855, 0.145
# [[2927  114]
#  [ 121 1360]]
#               precision    recall  f1-score   support
#
#          all     0.9603    0.9625    0.9614      3041
#          hem     0.9227    0.9183    0.9205      1481
#
#     accuracy                         0.9480      4522
#    macro avg     0.9415    0.9404    0.9409      4522
# weighted avg     0.9480    0.9480    0.9480      4522
#
#
#
# Confusion Matrix - Thresholds: 0.86, 0.14
# [[2920  121]
#  [ 120 1361]]
#               precision    recall  f1-score   support
#
#          all     0.9605    0.9602    0.9604      3041
#          hem     0.9184    0.9190    0.9187      1481
#
#     accuracy                         0.9467      4522
#    macro avg     0.9394    0.9396    0.9395      4522
# weighted avg     0.9467    0.9467    0.9467      4522
#
#
#
# Confusion Matrix - Thresholds: 0.865, 0.135
# [[2919  122]
#  [ 120 1361]]
#               precision    recall  f1-score   support
#
#          all     0.9605    0.9599    0.9602      3041
#          hem     0.9177    0.9190    0.9184      1481
#
#     accuracy                         0.9465      4522
#    macro avg     0.9391    0.9394    0.9393      4522
# weighted avg     0.9465    0.9465    0.9465      4522
#
#
#
# Confusion Matrix - Thresholds: 0.87, 0.13
# [[2916  125]
#  [ 120 1361]]
#               precision    recall  f1-score   support
#
#          all     0.9605    0.9589    0.9597      3041
#          hem     0.9159    0.9190    0.9174      1481
#
#     accuracy                         0.9458      4522
#    macro avg     0.9382    0.9389    0.9386      4522
# weighted avg     0.9459    0.9458    0.9458      4522
#
#
#
# Confusion Matrix - Thresholds: 0.875, 0.125
# [[2913  128]
#  [ 119 1362]]
#               precision    recall  f1-score   support
#
#          all     0.9608    0.9579    0.9593      3041
#          hem     0.9141    0.9196    0.9169      1481
#
#     accuracy                         0.9454      4522
#    macro avg     0.9374    0.9388    0.9381      4522
# weighted avg     0.9455    0.9454    0.9454      4522
#
#
#
# Confusion Matrix - Thresholds: 0.88, 0.12
# [[2904  137]
#  [ 118 1363]]
#               precision    recall  f1-score   support
#
#          all     0.9610    0.9549    0.9579      3041
#          hem     0.9087    0.9203    0.9145      1481
#
#     accuracy                         0.9436      4522
#    macro avg     0.9348    0.9376    0.9362      4522
# weighted avg     0.9438    0.9436    0.9437      4522
#
#
#
# Confusion Matrix - Thresholds: 0.885, 0.115
# [[2899  142]
#  [ 116 1365]]
#               precision    recall  f1-score   support
#
#          all     0.9615    0.9533    0.9574      3041
#          hem     0.9058    0.9217    0.9137      1481
#
#     accuracy                         0.9429      4522
#    macro avg     0.9336    0.9375    0.9355      4522
# weighted avg     0.9433    0.9429    0.9431      4522
#
#
#
# Confusion Matrix - Thresholds: 0.89, 0.11
# [[2892  149]
#  [ 115 1366]]
#               precision    recall  f1-score   support
#
#          all     0.9618    0.9510    0.9563      3041
#          hem     0.9017    0.9223    0.9119      1481
#
#     accuracy                         0.9416      4522
#    macro avg     0.9317    0.9367    0.9341      4522
# weighted avg     0.9421    0.9416    0.9418      4522
#
#
#
# Confusion Matrix - Thresholds: 0.895, 0.105
# [[2884  157]
#  [ 112 1369]]
#               precision    recall  f1-score   support
#
#          all     0.9626    0.9484    0.9554      3041
#          hem     0.8971    0.9244    0.9105      1481
#
#     accuracy                         0.9405      4522
#    macro avg     0.9299    0.9364    0.9330      4522
# weighted avg     0.9412    0.9405    0.9407      4522
#
#
#
# Confusion Matrix - Thresholds: 0.9, 0.1
# [[2877  164]
#  [ 108 1373]]
#               precision    recall  f1-score   support
#
#          all     0.9638    0.9461    0.9549      3041
#          hem     0.8933    0.9271    0.9099      1481
#
#     accuracy                         0.9398      4522
#    macro avg     0.9286    0.9366    0.9324      4522
# weighted avg     0.9407    0.9398    0.9401      4522

# %% [markdown]
# ### **Threshold optimization results**

# %%
# results
best_acc_ndx = np.argmax(np.array(acc_list))
best_pre_ndx = np.argmax(np.array(pre_list))
best_w_pre_ndx = np.argmax(np.array(w_pre_list))
best_rec_ndx = np.argmax(np.array(rec_list))
best_w_rec_ndx = np.argmax(np.array(w_rec_list))
best_f1_ndx = np.argmax(np.array(f1_list))
best_w_f1_ndx = np.argmax(np.array(w_f1_list))

print(f'For the threshold adjustments on test set predictions for the stacking ensemble')
print(f'Best accuracy           - threshold [{round(0.4+0.005*best_acc_ndx,3)},{round(0.6-0.005*best_acc_ndx,3)}] -> {round(acc_list[best_acc_ndx]*100,3)}%')
print(f'Best ALL precision      - threshold [{round(0.4+0.005*best_pre_ndx,3)},{round(0.6-0.005*best_pre_ndx,3)}] -> {round(pre_list[best_pre_ndx]*100,3)}%')
print(f'Best weighted precision - threshold [{round(0.4+0.005*best_w_pre_ndx,3)},{round(0.6-0.005*best_w_pre_ndx,3)}] -> {round(w_pre_list[best_w_pre_ndx]*100,3)}%')
print(f'Best ALL recall         - threshold [{round(0.4+0.005*best_rec_ndx,3)},{round(0.6-0.005*best_rec_ndx,3)}] -> {round(rec_list[best_rec_ndx]*100,3)}%')
print(f'Best weighted recall    - threshold [{round(0.4+0.005*best_w_rec_ndx,3)},{round(0.6-0.005*best_w_rec_ndx,3)}] -> {round(w_rec_list[best_w_rec_ndx]*100,3)}%')
print(f'Best ALL f1-score       - threshold [{round(0.4+0.005*best_f1_ndx,3)},{round(0.6-0.005*best_f1_ndx,3)}] -> {round(f1_list[best_f1_ndx]*100,3)}%')
print(f'Best weighted f1-score  - threshold [{round(0.4+0.005*best_w_f1_ndx,3)},{round(0.6-0.005*best_w_f1_ndx,3)}] -> {round(w_f1_list[best_w_f1_ndx]*100,3)}%')
# Out:
# For the threshold adjustments on test set predictions for the stacking ensemble
# Best accuracy           - threshold [0.69,0.31] -> 95.843%
# Best ALL precision      - threshold [0.9,0.1] -> 96.382%
# Best weighted precision - threshold [0.69,0.31] -> 95.892%
# Best ALL recall         - threshold [0.4,0.6] -> 99.277%
# Best weighted recall    - threshold [0.69,0.31] -> 95.843%
# Best ALL f1-score       - threshold [0.69,0.31] -> 96.965%
# Best weighted f1-score  - threshold [0.71,0.29] -> 95.801%

# %% [markdown]
# ### **Apply the optimal threshold and get adjusted metrics**

# %%
# Apply the threshold of the chosen criteria
best_ndx = best_w_f1_ndx # Here we use Weighted F1 score. Change here if you want a different criteria

threshold = round(0.6 - 0.005*best_ndx, 3)
y_pred_adjusted = (y_pred_probs >= threshold).astype(int) # Applying the adjusted thresholds for each class
cm = confusion_matrix(test_gen.classes, y_pred_adjusted)

#print adjusted metrics
print(f'Threshold used for adjusted predictions is: [ {round(0.4+0.005*best_ndx,3)} , {round(0.6-0.005*best_ndx,3)} ]')
print('')
print('Confusion matrix:')
plot_confusion_matrix(cm= cm, classes= classes, title = 'Confusion Matrix (Stacking Ensemble - Test Set [Adjusted])')

print(classification_report(test_gen.classes, y_pred_adjusted, target_names= classes, digits= 4))

print(f'Change in accuracy           : {round((acc_list[best_ndx]-acc_list[0])*100,3)} %')
print(f'Change in ALL precision      : {round((pre_list[best_ndx]-pre_list[0])*100,3)} %')
print(f'Change in weighted precision : {round((w_pre_list[best_ndx]-w_pre_list[0])*100,3)} %')
print(f'Change in ALL recall         : {round((rec_list[best_ndx]-rec_list[0])*100,3)} %')
print(f'Change in weighted recall    : {round((w_rec_list[best_ndx]-w_rec_list[0])*100,3)} %')
print(f'Change in ALL F1-score       : {round((f1_list[best_ndx]-f1_list[0])*100,3)} %')
print(f'Change in weighted F1-score  : {round((w_f1_list[best_ndx]-w_f1_list[0])*100,3)} %')

# Append metrics of the adjusted performance
acc_scores.append(accuracy_score(test_gen.classes, y_pred_adjusted))
pre_scores.append( precision_score(test_gen.classes, y_pred_adjusted, pos_label= 0))
w_pre_scores.append( precision_score(test_gen.classes, y_pred_adjusted, average='weighted'))
rec_scores.append(recall_score(test_gen.classes, y_pred_adjusted, pos_label= 0))
w_rec_scores.append(recall_score(test_gen.classes, y_pred_adjusted, average='weighted'))
f1_scores.append(f1_score(test_gen.classes, y_pred_adjusted, pos_label= 0))
w_f1_scores.append(f1_score(test_gen.classes, y_pred_adjusted, average='weighted'))
# Out:
# Threshold used for adjusted predictions is: [ 0.71 , 0.29 ]
#
# Confusion matrix:
# Confusion Matrix, Without Normalization
# [[3000   41]
#  [ 147 1334]]
#               precision    recall  f1-score   support
#
#          all     0.9533    0.9865    0.9696      3041
#          hem     0.9702    0.9007    0.9342      1481
#
#     accuracy                         0.9584      4522
#    macro avg     0.9617    0.9436    0.9519      4522
# weighted avg     0.9588    0.9584    0.9580      4522
#
# Change in accuracy           : 1.039 %
# Change in ALL precision      : 1.919 %
# Change in weighted precision : 0.873 %
# Change in ALL recall         : -0.625 %
# Change in weighted recall    : 1.039 %
# Change in ALL F1-score       : 0.708 %
# Change in weighted F1-score  : 1.098 %

# %% [markdown]
# # **Compare and display results**

# %% [markdown]
# ### **Metrics for individual models and stacking ensemble**

# %%
print(f'          Acc     ALL-Pre W-Pre   ALL-Rec W-Rec   ALL-F1  W-F1')
for x in range(4):
  print(f'Model {x+1} : {round(acc_scores[x]*100,3)}%  {round(pre_scores[x]*100,3)}%  {round(w_pre_scores[x]*100,3)}%  {round(rec_scores[x]*100,3)}%  {round(w_rec_scores[x]*100,3)}%  {round(f1_scores[x]*100,3)}%  {round(w_f1_scores[x]*100,3)}% ')
print(f'Stacking: {round(acc_scores[4]*100,3)}%  {round(pre_scores[4]*100,3)}%  {round(w_pre_scores[4]*100,3)}%  {round(rec_scores[4]*100,3)}%  {round(w_rec_scores[4]*100,3)}%  {round(f1_scores[4]*100,3)}%  {round(w_f1_scores[4]*100,3)}% ')
# Out:
#           Acc     ALL-Pre W-Pre   ALL-Rec W-Rec   ALL-F1  W-F1
# Model 1 : 94.892%  94.099%  94.978%  98.586%  94.892%  96.29%  94.82%
# Model 2 : 92.636%  92.794%  92.622%  96.547%  92.636%  94.633%  92.549%
# Model 3 : 90.491%  92.072%  90.422%  93.949%  90.491%  93.001%  90.437%
# Model 4 : 90.69%  89.963%  90.828%  96.975%  90.69%  93.338%  90.46%
# Stacking: 95.843%  95.329%  95.882%  98.652%  95.843%  96.962%  95.801%

# %% [markdown]
# ### **Save adjusted test set predictions**

# %%
y_pred_probs2 = [1 - x for x in y_pred_probs]
y_pred_adjusted2 = [ 1 ^ x for x in y_pred_adjusted]
classes = [1 ^ x for x in test_gen.classes]

pred_test_cells = np.column_stack((meta_input_val, y_pred_probs2, y_pred_adjusted2, classes)) # for display
predictions = np.column_stack((test_gen.filenames, meta_input_val, y_pred_probs2, y_pred_adjusted2, classes)) # for saving to CSV

# Save to CSV files
predictions_df = pd.DataFrame(
    predictions, columns = ['filenames',
                            f'{model1_name}-all-prob',
                            f'{model2_name}-all-prob',
                            f'{model3_name}-all-prob',
                            f'{model4_name}-all-prob',
                            f'stack-top-{model_count}_all_prob',
                            f'stack-top-{model_count}_adjusted_pred',
                            'actual_class'])
predictions_df.to_csv(f'/content/drive/MyDrive/ClassCSV/ALL-9010-stacking-top-{model_count}-adjusted-test-set-preds.csv', index= False)
print('Saved test set predictions into a CSV file')
print('')
# Out:
# Saved test set predictions into a CSV file

# %% [markdown]
# ## **Save meta model and weights**

# %%
# Save model and weights
meta_model.save(f'/content/drive/MyDrive/Models/ALL-9010-meta-model-top-{model_count}.h5')
print('')
print('Model successfully saved!')
meta_model.save_weights(f'/content/drive/MyDrive/Models/ALL-9010-meta-model-top-{model_count}-weights.h5')
print('Model weights successfully saved!')
# Out:
# Model successfully saved!
# Model weights successfully saved!

# %% [markdown]
# # **Display adjusted predictions**

# %%
# print adjusted predictions
print(f'Table of adjusted predictions in test set')
print()
print(f'Threshold for ALL: {round(0.5+0.005*best_ndx,3)} Stacked Probability')
print()
print(f'Model 1: {model1_name}')
print(f'Model 2: {model2_name}')
print(f'Model 3: {model3_name}')
print(f'Model 4: {model4_name}')
print()
print('Labels: [0 - HEM, 1 - ALL]')
print('---------------------------------------------------------------------')
print('  Model 1    Model 2    Model 3    Model 4    StackProb  StackPred  ActualClass')

import sys
with np.printoptions(threshold=sys.maxsize, suppress= True, linewidth= 300):
    print(pred_test_cells)
# Out:
# Table of adjusted predictions in test set
#
# Threshold for ALL: 0.81 Stacked Probability
#
# Model 1: ConvNeXtTiny
# Model 2: MobileNetV2
# Model 3: EfficientNetV2B3
# Model 4: DenseNet121
#
# Labels: [0 - HEM, 1 - ALL]
# ---------------------------------------------------------------------
#   Model 1    Model 2    Model 3    Model 4    StackProb  StackPred  ActualClass
# [[0.99129069 0.98813498 0.96085072 0.95367104 0.99080426 1.         1.        ]
#  [0.99678826 0.99642271 0.98740202 0.98595816 0.99174726 1.         1.        ]
#  [0.99691999 0.99497283 0.98278737 0.98879099 0.9916572  1.         1.        ]
#  [0.99601537 0.99626321 0.9881171  0.9882549  0.99175519 1.         1.        ]
#  [0.99638855 0.99608541 0.98568338 0.98493898 0.99169564 1.         1.        ]
#  [0.99584019 0.99237776 0.9762733  0.96950328 0.99137616 1.         1.        ]
#  [0.99417007 0.98782468 0.96429449 0.97460848 0.99106288 1.         1.        ]
#  [0.99143243 0.9961766  0.98137766 0.98102301 0.99147314 1.         1.        ]
#  [0.98365891 0.97480214 0.97371972 0.96643341 0.99086732 1.         1.        ]
#  [0.99413955 0.99097967 0.99299812 0.97100741 0.99168217 1.         1.        ]
#  [0.98626339 0.54052228 0.92570889 0.92456484 0.97578675 1.         1.        ]
#  [0.98583454 0.98451948 0.97855115 0.93625242 0.99093378 1.         1.        ]
#  [0.99931622 0.9930976  0.98405772 0.97777802 0.99166787 1.         1.        ]
#  [0.99873739 0.99038249 0.99136364 0.95408976 0.99165213 1.         1.        ]
#  [0.99654996 0.99591368 0.98587567 0.9597044  0.99156213 1.         1.        ]
#  [0.99465275 0.99445361 0.98543429 0.97333556 0.99157691 1.         1.        ]
#  [0.99525672 0.98613167 0.9876852  0.97196501 0.99156904 1.         1.        ]
#  [0.99630535 0.99395162 0.98981398 0.99022382 0.99178815 1.         1.        ]
#  [0.99758434 0.99279392 0.97524351 0.99110425 0.99147725 1.         1.        ]
#  [0.97789192 0.99203473 0.99067152 0.97363091 0.9912802  1.         1.        ]
#  [0.99171317 0.99592209 0.99253666 0.98962629 0.99175125 1.         1.        ]
#  [0.96329999 0.54891753 0.88989002 0.90130281 0.97229356 1.         1.        ]
#  [0.99756855 0.99536383 0.98898381 0.99257058 0.99182039 1.         1.        ]
#  [0.99221605 0.94052464 0.97896302 0.73096049 0.98839104 1.         1.        ]
#  [0.99172723 0.99220133 0.98026443 0.96863025 0.99135953 1.         1.        ]
#  [0.9951697  0.98860103 0.98533809 0.98117197 0.99158722 1.         1.        ]
#  [0.99751699 0.99646384 0.99186498 0.97782737 0.99180996 1.         1.        ]
#  [0.99500978 0.98461699 0.99193442 0.97279704 0.99164444 1.         1.        ]
#  [0.98659581 0.95106637 0.98327911 0.93109381 0.99067622 1.         1.        ]
#  [0.99075657 0.98755533 0.99239361 0.98854989 0.99165493 1.         1.        ]
#  [0.74184239 0.49309582 0.99583191 0.99043816 0.95626646 1.         1.        ]
#  [0.99224442 0.98151058 0.39150783 0.9493981  0.94263458 1.         1.        ]
#  [0.87197745 0.85548735 0.34405091 0.84690118 0.88909966 1.         1.        ]
#  [0.95916009 0.77249342 0.98342782 0.96821946 0.98635572 1.         1.        ]
#  [0.98964322 0.98478067 0.94901001 0.98825872 0.99054599 1.         1.        ]
#  [0.98979133 0.98297989 0.98863214 0.98678583 0.99150747 1.         1.        ]
#  [0.99432677 0.9865064  0.97984993 0.95706534 0.9913013  1.         1.        ]
#  [0.96701503 0.25296751 0.88523096 0.95689529 0.94291788 1.         1.        ]
#  [0.99078584 0.98748428 0.99059033 0.98540515 0.99160427 1.         1.        ]
#  [0.99435812 0.9909156  0.98668772 0.99118292 0.9916563  1.         1.        ]
#  [0.98992598 0.98950642 0.94573265 0.97404319 0.99050701 1.         1.        ]
#  [0.99325949 0.98867059 0.9930079  0.97174698 0.99165052 1.         1.        ]
#  [0.50212961 0.91720718 0.95399415 0.96369958 0.93250632 1.         1.        ]
#  [0.99874771 0.99062425 0.98965806 0.99120539 0.99181926 1.         1.        ]
#  [0.98333597 0.99077356 0.96796238 0.96942264 0.99087828 1.         1.        ]
#  [0.99739361 0.99102879 0.98627579 0.9877094  0.99170649 1.         1.        ]
#  [0.99348748 0.99176735 0.98830682 0.99254507 0.99168217 1.         1.        ]
#  [0.75859827 0.95211488 0.96098489 0.72925442 0.97503573 1.         1.        ]
#  [0.99377972 0.98720956 0.99042225 0.99139601 0.9916929  1.         1.        ]
#  [0.61150134 0.93906665 0.95505583 0.06384403 0.89314127 1.         1.        ]
#  [0.99472529 0.99076182 0.98844111 0.99219114 0.99170476 1.         1.        ]
#  [0.99427742 0.96965671 0.98548084 0.97206187 0.99137515 1.         1.        ]
#  [0.98461622 0.98607129 0.99085099 0.90895951 0.99094415 1.         1.        ]
#  [0.52863407 0.97483206 0.56344277 0.90343273 0.8561551  1.         1.        ]
#  [0.99305636 0.98932844 0.99347419 0.9656654  0.9916262  1.         1.        ]
#  [0.99690479 0.93372291 0.99232846 0.99113536 0.99112761 1.         1.        ]
#  [0.97795963 0.97540808 0.87932247 0.72070879 0.98566675 1.         1.        ]
#  [0.98746324 0.992145   0.98342657 0.9764865  0.99136907 1.         1.        ]
#  [0.98265809 0.97798961 0.99062753 0.98605937 0.99133354 1.         1.        ]
#  [0.99126279 0.99024498 0.9799968  0.96748382 0.99132204 1.         1.        ]
#  [0.93214411 0.99112201 0.98250157 0.98382008 0.98980629 1.         1.        ]
#  [0.99019927 0.97665888 0.98799729 0.98383373 0.99144    1.         1.        ]
#  [0.99454933 0.98360968 0.98149198 0.89224631 0.99081504 1.         1.        ]
#  [0.98930091 0.9810729  0.98585135 0.98455054 0.99141067 1.         1.        ]
#  [0.96625227 0.96381366 0.93707395 0.96577835 0.98929381 1.         1.        ]
#  [0.98977482 0.99896359 0.9902339  0.98992819 0.99168265 1.         1.        ]
#  [0.95207489 0.66098595 0.87463367 0.89984125 0.97707224 1.         1.        ]
#  [0.99425149 0.98427701 0.99061805 0.98736805 0.991669   1.         1.        ]
#  [0.99643862 0.98961747 0.99230349 0.98864508 0.99180233 1.         1.        ]
#  [0.9931097  0.98966813 0.97065175 0.93939304 0.99099034 1.         1.        ]
#  [0.99464524 0.99015617 0.98757565 0.8920278  0.99099088 1.         1.        ]
#  [0.9954977  0.99400216 0.99466681 0.99337691 0.99188268 1.         1.        ]
#  [0.9901154  0.9916088  0.98284698 0.98331231 0.99144667 1.         1.        ]
#  [0.99046224 0.98553896 0.96494019 0.93105924 0.9907065  1.         1.        ]
#  [0.97668308 0.98320514 0.96598947 0.95582455 0.99052727 1.         1.        ]
#  [0.97983164 0.98752916 0.91189653 0.98532701 0.98918694 1.         1.        ]
#  [0.98370343 0.98947012 0.98250246 0.98487675 0.99127078 1.         1.        ]
#  [0.99597162 0.98028952 0.98981804 0.98712045 0.99165982 1.         1.        ]
#  [0.99586898 0.98892421 0.98700351 0.98746151 0.99166822 1.         1.        ]
#  [0.99323177 0.99370015 0.98860627 0.93618292 0.99139339 1.         1.        ]
#  [0.98011351 0.98586881 0.98801917 0.98027885 0.99125528 1.         1.        ]
#  [0.95361024 0.96394235 0.98108131 0.98483551 0.9901458  1.         1.        ]
#  [0.95071131 0.97720182 0.92519611 0.36228657 0.97618079 1.         1.        ]
#  [0.99405646 0.9866001  0.98943299 0.99545419 0.99168861 1.         1.        ]
#  [0.9919796  0.983051   0.991319   0.93862879 0.99134725 1.         1.        ]
#  [0.98926091 0.98807728 0.95985734 0.98284769 0.99085873 1.         1.        ]
#  [0.95034868 0.96507925 0.93551171 0.65684777 0.98498905 1.         1.        ]
#  [0.98289078 0.9718883  0.9859013  0.98412329 0.99117517 1.         1.        ]
#  [0.98760706 0.98808205 0.9902851  0.9899776  0.99154478 1.         1.        ]
#  [0.98437381 0.80235147 0.93510789 0.98728496 0.98628306 1.         1.        ]
#  [0.99252921 0.98196548 0.96017003 0.98313683 0.99087429 1.         1.        ]
#  [0.99436694 0.99024117 0.98334992 0.99239433 0.99158257 1.         1.        ]
#  [0.98121119 0.98343062 0.96087998 0.95926124 0.99054557 1.         1.        ]
#  [0.96654427 0.9886806  0.98079497 0.98104799 0.99076885 1.         1.        ]
#  [0.97792232 0.81483603 0.97899503 0.97715968 0.98787332 1.         1.        ]
#  [0.98982608 0.98774242 0.98671037 0.98755336 0.99150872 1.         1.        ]
#  [0.9945327  0.9883433  0.98853743 0.97033316 0.99157709 1.         1.        ]
#  [0.91790771 0.99139434 0.98638284 0.98299271 0.98942333 1.         1.        ]
#  [0.98602945 0.98903185 0.98131371 0.9879753  0.99131083 1.         1.        ]
#  [0.98821449 0.96594107 0.82678866 0.19136371 0.96395224 1.         1.        ]
#  [0.98058599 0.98035747 0.91385287 0.98399043 0.98916018 1.         1.        ]
#  [0.99406117 0.99274749 0.98970383 0.9422676  0.99146318 1.         1.        ]
#  [0.99579948 0.9919979  0.98526728 0.96406543 0.99152905 1.         1.        ]
#  [0.9878757  0.98932248 0.99600631 0.98765546 0.99167401 1.         1.        ]
#  [0.99731052 0.99458224 0.99338657 0.99410063 0.99190521 1.         1.        ]
#  [0.99015182 0.98547667 0.99032414 0.98888898 0.99158108 1.         1.        ]
#  [0.9886381  0.99368048 0.98524469 0.97585344 0.99144268 1.         1.        ]
#  [0.98259336 0.98639965 0.9829433  0.9791767  0.99120373 1.         1.        ]
#  [0.99493933 0.98985636 0.97776264 0.98381293 0.99144071 1.         1.        ]
#  [0.96731591 0.84632063 0.97901398 0.91977125 0.98817098 1.         1.        ]
#  [0.99125469 0.98585391 0.97877455 0.97735775 0.99131358 1.         1.        ]
#  [0.98576653 0.98727292 0.94571996 0.94683725 0.9902578  1.         1.        ]
#  [0.99488235 0.99032474 0.97675937 0.9468171  0.99121684 1.         1.        ]
#  [0.98969871 0.99104804 0.9828456  0.96965885 0.99136388 1.         1.        ]
#  [0.99220395 0.98204482 0.99455005 0.98924178 0.99169338 1.         1.        ]
#  [0.98800975 0.94854194 0.99225509 0.98582524 0.99118215 1.         1.        ]
#  [0.98211229 0.99066156 0.98247796 0.98157066 0.99122715 1.         1.        ]
#  [0.99122483 0.98865861 0.99302661 0.98342913 0.9916662  1.         1.        ]
#  [0.99303693 0.98805094 0.99209678 0.9812243  0.99167341 1.         1.        ]
#  [0.98758173 0.99071968 0.98284054 0.9872508  0.99139351 1.         1.        ]
#  [0.98778397 0.99275547 0.95828515 0.973279   0.99080259 1.         1.        ]
#  [0.99030286 0.99280363 0.9919939  0.98347569 0.99165505 1.         1.        ]
#  [0.9891423  0.99094057 0.99035394 0.98921251 0.99160302 1.         1.        ]
#  [0.97909319 0.97844177 0.41778734 0.96757221 0.94530326 1.         1.        ]
#  [0.9936009  0.99088401 0.98887444 0.98557395 0.99166203 1.         1.        ]
#  [0.98772275 0.99073821 0.99321151 0.98325276 0.99160355 1.         1.        ]
#  [0.9880386  0.99221683 0.63941234 0.97518027 0.97513449 1.         1.        ]
#  [0.99714905 0.98521197 0.98777455 0.98725545 0.99168426 1.         1.        ]
#  [0.92184442 0.97503906 0.86730701 0.94663328 0.98535359 1.         1.        ]
#  [0.99109131 0.97817183 0.96754706 0.9876774  0.99099737 1.         1.        ]
#  [0.88071465 0.99012357 0.29925695 0.91081983 0.89793998 1.         1.        ]
#  [0.9944455  0.98529136 0.99240768 0.98157102 0.99169379 1.         1.        ]
#  [0.99351043 0.99295628 0.99186713 0.9934895  0.99177068 1.         1.        ]
#  [0.99668425 0.99489152 0.94059181 0.96161419 0.99054444 1.         1.        ]
#  [0.99737334 0.99010998 0.98841929 0.98186666 0.99171478 1.         1.        ]
#  [0.98443836 0.99648225 0.98502129 0.9558996  0.99124968 1.         1.        ]
#  [0.76496619 0.99065232 0.98004144 0.97880781 0.98145705 1.         1.        ]
#  [0.99171704 0.99234688 0.991189   0.98149318 0.99165702 1.         1.        ]
#  [0.99304479 0.97914553 0.98960471 0.98319983 0.991561   1.         1.        ]
#  [0.99777102 0.99217212 0.98407841 0.99538028 0.9916904  1.         1.        ]
#  [0.7290405  0.98776615 0.98420334 0.73834181 0.97442943 1.         1.        ]
#  [0.9953264  0.99256849 0.99297285 0.99359858 0.99183333 1.         1.        ]
#  [0.99301755 0.99153918 0.98994094 0.98176253 0.99165672 1.         1.        ]
#  [0.99626333 0.99304563 0.98957294 0.99048984 0.99177605 1.         1.        ]
#  [0.96927005 0.98921996 0.99307382 0.98619741 0.99115074 1.         1.        ]
#  [0.99527174 0.98941606 0.98450828 0.96369815 0.99148053 1.         1.        ]
#  [0.99543709 0.98267591 0.97497976 0.98840976 0.99132437 1.         1.        ]
#  [0.98589897 0.97200102 0.96547812 0.98321849 0.99076205 1.         1.        ]
#  [0.99539435 0.9922387  0.98747069 0.99338573 0.99171644 1.         1.        ]
#  [0.99222809 0.9869104  0.95207757 0.88393831 0.99010485 1.         1.        ]
#  [0.98785782 0.98786366 0.97753376 0.98803395 0.99126279 1.         1.        ]
#  [0.99152583 0.94982171 0.97867328 0.94414228 0.99079305 1.         1.        ]
#  [0.9915365  0.98524809 0.977754   0.94099075 0.99108648 1.         1.        ]
#  [0.98568428 0.98809063 0.9814772  0.94825476 0.99109399 1.         1.        ]
#  [0.9972403  0.9904694  0.99028951 0.99000531 0.99179155 1.         1.        ]
#  [0.98651683 0.97624981 0.98842853 0.98285866 0.99135238 1.         1.        ]
#  [0.84581614 0.97727156 0.98668939 0.86667705 0.98546791 1.         1.        ]
#  [0.99422508 0.99250108 0.9914096  0.96530747 0.99163073 1.         1.        ]
#  [0.9825058  0.98880577 0.95405632 0.92840338 0.99026638 1.         1.        ]
#  [0.99840206 0.99035609 0.99397779 0.98401916 0.99186248 1.         1.        ]
#  [0.93656611 0.97752815 0.91626036 0.86560827 0.98717427 1.         1.        ]
#  [0.29304183 0.98864639 0.17805587 0.44366831 0.38851368 0.         1.        ]
#  [0.995561   0.98600024 0.98857367 0.97918177 0.9916333  1.         1.        ]
#  [0.98596787 0.98252434 0.98615706 0.78429615 0.98954946 1.         1.        ]
#  [0.92265707 0.98235416 0.74457765 0.67638516 0.9759258  1.         1.        ]
#  [0.98917794 0.98462462 0.94777191 0.98198926 0.99049646 1.         1.        ]
#  [0.99624461 0.99104089 0.97615439 0.96579081 0.9913516  1.         1.        ]
#  [0.99591273 0.98853368 0.95720178 0.95690203 0.99085271 1.         1.        ]
#  [0.9850772  0.96874642 0.92850798 0.95030755 0.98957634 1.         1.        ]
#  [0.98703659 0.9894672  0.97546911 0.97317761 0.99114799 1.         1.        ]
#  [0.99137372 0.99043685 0.98433346 0.98028803 0.99148661 1.         1.        ]
#  [0.99550641 0.98816419 0.99147636 0.99132895 0.99176288 1.         1.        ]
#  [0.99623859 0.99008381 0.98903775 0.98459065 0.99171585 1.         1.        ]
#  [0.98264539 0.98827422 0.98391551 0.99101323 0.99129105 1.         1.        ]
#  [0.99499029 0.99067515 0.99080265 0.98965025 0.99175006 1.         1.        ]
#  [0.9924953  0.98809451 0.98812896 0.9704349  0.99152166 1.         1.        ]
#  [0.99520063 0.99073011 0.99150109 0.98925447 0.99176848 1.         1.        ]
#  [0.99690777 0.98646891 0.9924413  0.98987585 0.99179667 1.         1.        ]
#  [0.99568838 0.99008369 0.99288768 0.99022114 0.99180746 1.         1.        ]
#  [0.99198616 0.98676318 0.98327339 0.98904574 0.99148446 1.         1.        ]
#  [0.99538273 0.98922485 0.99109602 0.98535824 0.9917357  1.         1.        ]
#  [0.98115987 0.98257118 0.96864229 0.97604942 0.99079406 1.         1.        ]
#  [0.99366391 0.99296373 0.9886601  0.98603421 0.9916774  1.         1.        ]
#  [0.9900592  0.99368215 0.99167293 0.97501618 0.99160439 1.         1.        ]
#  [0.98883748 0.99401134 0.99142051 0.97409952 0.99156868 1.         1.        ]
#  [0.99478626 0.98863834 0.98646104 0.98795342 0.99163067 1.         1.        ]
#  [0.99403137 0.9899053  0.98851097 0.9914819  0.99168032 1.         1.        ]
#  [0.98498905 0.99279106 0.98741651 0.97981399 0.99141645 1.         1.        ]
#  [0.99144721 0.97852308 0.96827579 0.97835654 0.99102205 1.         1.        ]
#  [0.99372041 0.99196023 0.98977202 0.99096185 0.99171394 1.         1.        ]
#  [0.98461145 0.98900503 0.98819858 0.98086423 0.99139822 1.         1.        ]
#  [0.9967519  0.98766673 0.99024361 0.9868902  0.99174434 1.         1.        ]
#  [0.99097997 0.98538488 0.98648757 0.98839951 0.99151582 1.         1.        ]
#  [0.97768056 0.98728579 0.98473412 0.98131895 0.99113739 1.         1.        ]
#  [0.98974609 0.98508239 0.62058955 0.80908972 0.97319549 1.         1.        ]
#  [0.99816614 0.9941467  0.98949707 0.98820251 0.99181592 1.         1.        ]
#  [0.99486357 0.98898357 0.99001533 0.98283434 0.99168754 1.         1.        ]
#  [0.99134129 0.98301864 0.98950434 0.9841426  0.99155325 1.         1.        ]
#  [0.99593002 0.9883008  0.98671246 0.98613459 0.99165326 1.         1.        ]
#  [0.99565661 0.98946804 0.98843378 0.98117983 0.99166805 1.         1.        ]
#  [0.98895895 0.98768669 0.97764426 0.9731065  0.99122828 1.         1.        ]
#  [0.99244952 0.97321713 0.98421764 0.97673941 0.99135464 1.         1.        ]
#  [0.99716395 0.99181056 0.9912464  0.98733705 0.9918077  1.         1.        ]
#  [0.99436426 0.99214059 0.99264079 0.99037105 0.99178827 1.         1.        ]
#  [0.98728335 0.99393904 0.99054283 0.98252964 0.99155915 1.         1.        ]
#  [0.99669814 0.98456442 0.97812611 0.98469979 0.99144506 1.         1.        ]
#  [0.98890799 0.99185282 0.98890078 0.98878354 0.99157202 1.         1.        ]
#  [0.99342865 0.98923767 0.98464668 0.98074704 0.99153459 1.         1.        ]
#  [0.99101138 0.98733854 0.95416778 0.93659526 0.9905194  1.         1.        ]
#  [0.99548256 0.99037558 0.99284333 0.98610514 0.99178571 1.         1.        ]
#  [0.98235655 0.98949111 0.99010676 0.98191148 0.99139321 1.         1.        ]
#  [0.99544853 0.98879761 0.9867093  0.99117368 0.99166554 1.         1.        ]
#  [0.99452293 0.98808783 0.98641998 0.99442285 0.9916414  1.         1.        ]
#  [0.99189371 0.98829365 0.99362683 0.99217844 0.99172777 1.         1.        ]
#  [0.99238974 0.91540104 0.96144593 0.9538914  0.98993409 1.         1.        ]
#  [0.99672616 0.97750574 0.99474299 0.98693061 0.99175787 1.         1.        ]
#  [0.98283732 0.98726171 0.90476829 0.95352757 0.98901623 1.         1.        ]
#  [0.99170458 0.98157907 0.98585027 0.98054355 0.99145687 1.         1.        ]
#  [0.99055862 0.99018878 0.99263835 0.98464346 0.99165988 1.         1.        ]
#  [0.99723685 0.99116874 0.98882091 0.98899239 0.9917624  1.         1.        ]
#  [0.99492234 0.98834223 0.99041498 0.97748077 0.99166417 1.         1.        ]
#  [0.98988974 0.97553521 0.93192852 0.96827197 0.98991007 1.         1.        ]
#  [0.98970371 0.98848009 0.98691386 0.98436052 0.99150342 1.         1.        ]
#  [0.98582506 0.97720075 0.97889382 0.97178304 0.99108475 1.         1.        ]
#  [0.98055375 0.98673266 0.9714244  0.97483891 0.99087447 1.         1.        ]
#  [0.99628627 0.99233598 0.99180263 0.9866969  0.99179965 1.         1.        ]
#  [0.99763083 0.99090379 0.99238974 0.99171197 0.99185425 1.         1.        ]
#  [0.99418527 0.9904542  0.98555493 0.98591578 0.99160367 1.         1.        ]
#  [0.98312771 0.98942763 0.98107636 0.98501855 0.991225   1.         1.        ]
#  [0.99556583 0.98519737 0.98702985 0.97276783 0.99156028 1.         1.        ]
#  [0.98512036 0.97975117 0.97906828 0.98466289 0.9911465  1.         1.        ]
#  [0.99520665 0.99190009 0.9904027  0.98919135 0.99175465 1.         1.        ]
#  [0.9942655  0.98467308 0.99060845 0.9810316  0.99164486 1.         1.        ]
#  [0.99601823 0.99180484 0.98712885 0.98625135 0.9916923  1.         1.        ]
#  [0.9867819  0.9871307  0.96877462 0.97913659 0.99099511 1.         1.        ]
#  [0.99612314 0.9765054  0.91905981 0.97742897 0.98965889 1.         1.        ]
#  [0.98269027 0.98836845 0.97927791 0.9671368  0.99108565 1.         1.        ]
#  [0.99289858 0.98991805 0.98348296 0.96772188 0.99143189 1.         1.        ]
#  [0.99536514 0.98950374 0.98948342 0.98104823 0.99168235 1.         1.        ]
#  [0.99580705 0.98871291 0.99235958 0.98438901 0.99176252 1.         1.        ]
#  [0.99550337 0.98949385 0.98445421 0.97349215 0.99154085 1.         1.        ]
#  [0.99136633 0.97947514 0.89060277 0.98151428 0.98861343 1.         1.        ]
#  [0.94774944 0.97299045 0.70049787 0.94987798 0.97681403 1.         1.        ]
#  [0.99710399 0.99409133 0.98940593 0.98239142 0.99175966 1.         1.        ]
#  [0.98667705 0.99255317 0.97308707 0.92527825 0.99082828 1.         1.        ]
#  [0.99702102 0.99275029 0.98946464 0.99153262 0.9917931  1.         1.        ]
#  [0.99412811 0.99331194 0.99406403 0.99375206 0.99183464 1.         1.        ]
#  [0.97884411 0.98376036 0.97389519 0.89773124 0.99034762 1.         1.        ]
#  [0.99487656 0.98680252 0.9785648  0.96492809 0.99133462 1.         1.        ]
#  [0.99560839 0.95434529 0.99289399 0.99057204 0.99144679 1.         1.        ]
#  [0.99325365 0.9915399  0.97674108 0.97161204 0.99133259 1.         1.        ]
#  [0.99152386 0.98839581 0.97835815 0.95695299 0.99121779 1.         1.        ]
#  [0.9902429  0.9609316  0.98609978 0.98104674 0.9912532  1.         1.        ]
#  [0.9970693  0.99122459 0.99350959 0.98916417 0.99185604 1.         1.        ]
#  [0.99681276 0.98950827 0.98972869 0.98664969 0.99174839 1.         1.        ]
#  [0.99655151 0.99199134 0.99181443 0.99111193 0.99182355 1.         1.        ]
#  [0.99323761 0.9904269  0.98831022 0.98775148 0.99164683 1.         1.        ]
#  [0.99051929 0.93525499 0.95915461 0.96153355 0.9901827  1.         1.        ]
#  [0.993119   0.99268359 0.98798907 0.98095655 0.99162304 1.         1.        ]
#  [0.99749231 0.99051279 0.99385482 0.99124265 0.99187624 1.         1.        ]
#  [0.99325198 0.97760516 0.97866184 0.97490263 0.99128097 1.         1.        ]
#  [0.99243331 0.99029279 0.7863515  0.97019863 0.98449522 1.         1.        ]
#  [0.98918647 0.99368733 0.98621285 0.97767353 0.99148554 1.         1.        ]
#  [0.99361008 0.99164915 0.99173826 0.98545933 0.99172693 1.         1.        ]
#  [0.99187237 0.99252158 0.990044   0.98845845 0.99167085 1.         1.        ]
#  [0.98962516 0.99183673 0.98981768 0.98577267 0.9915967  1.         1.        ]
#  [0.99647254 0.98794156 0.99245632 0.99576318 0.99182028 1.         1.        ]
#  [0.98943263 0.9899767  0.9843722  0.98773116 0.9914676  1.         1.        ]
#  [0.98503625 0.96999556 0.98656392 0.97731358 0.99119937 1.         1.        ]
#  [0.99638063 0.9890759  0.96430868 0.98806876 0.99114072 1.         1.        ]
#  [0.99052376 0.99157411 0.98517609 0.9947148  0.99155211 1.         1.        ]
#  [0.99762625 0.98757941 0.98895824 0.9906193  0.99175227 1.         1.        ]
#  [0.99231917 0.97921067 0.97746104 0.97475117 0.99124444 1.         1.        ]
#  [0.99552828 0.99360621 0.99187088 0.98703021 0.99179476 1.         1.        ]
#  [0.99630749 0.99077785 0.99199849 0.99291974 0.99181914 1.         1.        ]
#  [0.995323   0.99263579 0.98816514 0.9761079  0.99165034 1.         1.        ]
#  [0.99453676 0.98822975 0.98966146 0.99235499 0.99170655 1.         1.        ]
#  [0.99447256 0.98949975 0.99341857 0.98872221 0.99177945 1.         1.        ]
#  [0.9929899  0.98850191 0.99141204 0.98312563 0.99167114 1.         1.        ]
#  [0.99536788 0.9824239  0.9893918  0.99166846 0.99166948 1.         1.        ]
#  [0.99253356 0.22377336 0.97190225 0.93620056 0.95443404 1.         1.        ]
#  [0.99088192 0.99024081 0.97276515 0.97889745 0.9912141  1.         1.        ]
#  [0.99303895 0.98970819 0.99125189 0.98742592 0.99169737 1.         1.        ]
#  [0.99492162 0.98718667 0.99398488 0.99114883 0.99179327 1.         1.        ]
#  [0.99679488 0.98936206 0.99152994 0.97399276 0.99171615 1.         1.        ]
#  [0.99453884 0.98788959 0.99471927 0.98336118 0.99177045 1.         1.        ]
#  [0.99383992 0.99062192 0.99128377 0.98514831 0.99171376 1.         1.        ]
#  [0.98697984 0.97100866 0.99067384 0.9784314  0.99135154 1.         1.        ]
#  [0.99706155 0.98363703 0.98257738 0.96987277 0.99147397 1.         1.        ]
#  [0.9947719  0.98819345 0.70813221 0.9686904  0.98024803 1.         1.        ]
#  [0.98869729 0.98905748 0.98885965 0.96883285 0.99144775 1.         1.        ]
#  [0.9949851  0.98661906 0.98760557 0.98324364 0.991624   1.         1.        ]
#  [0.9925493  0.98482263 0.98866218 0.98879075 0.99159706 1.         1.        ]
#  [0.99506444 0.99065197 0.98880953 0.9900232  0.9917112  1.         1.        ]
#  [0.99238163 0.97185373 0.97177142 0.93261832 0.99079871 1.         1.        ]
#  [0.97048092 0.98614466 0.98621595 0.96297699 0.99088949 1.         1.        ]
#  [0.99050212 0.98910147 0.99257243 0.97980118 0.99162543 1.         1.        ]
#  [0.99559623 0.97341394 0.97541863 0.97925287 0.99123991 1.         1.        ]
#  [0.99597013 0.99036437 0.99163544 0.98941201 0.99178696 1.         1.        ]
#  [0.99050432 0.99290997 0.97894204 0.99277365 0.99141747 1.         1.        ]
#  [0.97731316 0.98042727 0.98842132 0.97454959 0.99112469 1.         1.        ]
#  [0.99142116 0.98423564 0.96063876 0.9757387  0.99087811 1.         1.        ]
#  [0.9950664  0.98823816 0.98396021 0.98923546 0.99158585 1.         1.        ]
#  [0.99619031 0.90492368 0.98948157 0.98081297 0.990529   1.         1.        ]
#  [0.99689746 0.98762637 0.99325693 0.99204308 0.99183089 1.         1.        ]
#  [0.98118043 0.96843958 0.20045094 0.7639581  0.88367242 1.         1.        ]
#  [0.99307877 0.98737526 0.98628241 0.98453355 0.99156255 1.         1.        ]
#  [0.99559081 0.99017566 0.99288028 0.98505753 0.99178201 1.         1.        ]
#  [0.99239856 0.9924314  0.98924875 0.97801548 0.991615   1.         1.        ]
#  [0.99378729 0.98563808 0.99157494 0.98819858 0.99169242 1.         1.        ]
#  [0.99592292 0.98410046 0.95940614 0.99039418 0.99095488 1.         1.        ]
#  [0.99628723 0.98596364 0.9638325  0.98530209 0.99109316 1.         1.        ]
#  [0.99544466 0.99019921 0.98855573 0.97991657 0.99166429 1.         1.        ]
#  [0.99679679 0.99090624 0.99417228 0.99112731 0.99186933 1.         1.        ]
#  [0.99382222 0.99102914 0.99169791 0.98819399 0.9917385  1.         1.        ]
#  [0.99670035 0.98943007 0.99271154 0.98352873 0.99179024 1.         1.        ]
#  [0.99427032 0.98439807 0.98654675 0.97988647 0.99155229 1.         1.        ]
#  [0.99370265 0.9868657  0.95118976 0.82489067 0.9895252  1.         1.        ]
#  [0.99316347 0.988846   0.99310547 0.98873121 0.99173754 1.         1.        ]
#  [0.99150437 0.99020493 0.99192786 0.98172724 0.9916532  1.         1.        ]
#  [0.99534541 0.99107492 0.98871171 0.99143773 0.99172461 1.         1.        ]
#  [0.99188191 0.97523302 0.99032998 0.9658612  0.99143362 1.         1.        ]
#  [0.99537873 0.98174447 0.97507793 0.98649591 0.99131525 1.         1.        ]
#  [0.98263276 0.98990774 0.92812169 0.88222313 0.98927468 1.         1.        ]
#  [0.99408358 0.9884367  0.96851861 0.97734499 0.99117535 1.         1.        ]
#  [0.99646145 0.99184543 0.991808   0.99097365 0.99181962 1.         1.        ]
#  [0.99413329 0.99269378 0.98958975 0.98553526 0.99170303 1.         1.        ]
#  [0.99778652 0.98521322 0.88958341 0.98941886 0.98884016 1.         1.        ]
#  [0.99063838 0.99116397 0.5023483  0.96143681 0.96106917 1.         1.        ]
#  [0.99369013 0.9870134  0.98491699 0.96290201 0.991431   1.         1.        ]
#  [0.98717624 0.98752147 0.96542257 0.95512205 0.9908126  1.         1.        ]
#  [0.99740309 0.9927845  0.95025158 0.98362595 0.99083596 1.         1.        ]
#  [0.99779922 0.99142671 0.9667387  0.9856512  0.99125463 1.         1.        ]
#  [0.98728383 0.99355376 0.94705439 0.98684782 0.99053442 1.         1.        ]
#  [0.9971602  0.99005568 0.99237251 0.9911738  0.99183428 1.         1.        ]
#  [0.9949705  0.9881689  0.96716219 0.983365   0.9911713  1.         1.        ]
#  [0.99579728 0.99343902 0.98937804 0.99292666 0.99177361 1.         1.        ]
#  [0.98996991 0.99057919 0.97410077 0.98616391 0.99125397 1.         1.        ]
#  [0.98874718 0.99323577 0.98825604 0.98390144 0.99154603 1.         1.        ]
#  [0.99698037 0.98874599 0.98325551 0.94648165 0.99138957 1.         1.        ]
#  [0.99491984 0.98570257 0.97257882 0.98403847 0.99128181 1.         1.        ]
#  [0.99155664 0.99171817 0.99020034 0.98477918 0.99164498 1.         1.        ]
#  [0.98474556 0.99304175 0.98620075 0.96342534 0.99129874 1.         1.        ]
#  [0.99345893 0.99097812 0.99066705 0.98858589 0.99170959 1.         1.        ]
#  [0.98973292 0.99171585 0.99014097 0.965882   0.99150139 1.         1.        ]
#  [0.99316591 0.98947597 0.97906315 0.97541839 0.99138534 1.         1.        ]
#  [0.99414116 0.99307692 0.99062061 0.98828214 0.99173993 1.         1.        ]
#  [0.99338853 0.98737365 0.97487271 0.95604289 0.99117345 1.         1.        ]
#  [0.99499607 0.99437606 0.98889416 0.98929602 0.99173808 1.         1.        ]
#  [0.99471176 0.99154598 0.70588899 0.96811444 0.98020387 1.         1.        ]
#  [0.9751507  0.99067849 0.92545825 0.93561083 0.98940408 1.         1.        ]
#  [0.99219561 0.98501879 0.86342078 0.98362386 0.98772192 1.         1.        ]
#  [0.99368048 0.98978943 0.9892292  0.98697436 0.99166864 1.         1.        ]
#  [0.99180335 0.98565012 0.98333836 0.97352171 0.99140489 1.         1.        ]
#  [0.97970772 0.99022758 0.99230349 0.96901762 0.99131906 1.         1.        ]
#  [0.99193621 0.98054516 0.93515271 0.96365279 0.9901256  1.         1.        ]
#  [0.99716276 0.99409324 0.99064201 0.99239653 0.99183476 1.         1.        ]
#  [0.9802919  0.94629657 0.29991701 0.74326646 0.91334635 1.         1.        ]
#  [0.99592483 0.99348986 0.98577917 0.98604625 0.9916743  1.         1.        ]
#  [0.99655092 0.99072134 0.98668289 0.98980963 0.99170101 1.         1.        ]
#  [0.96915954 0.99745494 0.99242699 0.99326307 0.99123234 1.         1.        ]
#  [0.99376363 0.99549758 0.97446907 0.97953838 0.99136895 1.         1.        ]
#  [0.98244977 0.9821164  0.80783659 0.95581293 0.98498821 1.         1.        ]
#  [0.99564916 0.97252649 0.98772556 0.98100382 0.99152035 1.         1.        ]
#  [0.9939757  0.99042386 0.98888189 0.97599208 0.99161834 1.         1.        ]
#  [0.99699461 0.98963076 0.98927361 0.9832865  0.99172759 1.         1.        ]
#  [0.99677593 0.99386394 0.9887715  0.97924757 0.99172103 1.         1.        ]
#  [0.9925136  0.99317837 0.91101134 0.96210724 0.98956192 1.         1.        ]
#  [0.99171782 0.98852623 0.95799375 0.96396506 0.99081916 1.         1.        ]
#  [0.99593544 0.99198568 0.99153942 0.9866637  0.99178386 1.         1.        ]
#  [0.9974255  0.99245799 0.97264409 0.9710381  0.99134547 1.         1.        ]
#  [0.99681348 0.99181068 0.97061074 0.98817676 0.99133587 1.         1.        ]
#  [0.99363327 0.9940691  0.99127191 0.98857284 0.9917506  1.         1.        ]
#  [0.99145871 0.99454463 0.96501821 0.960244   0.99099296 1.         1.        ]
#  [0.96203172 0.98846859 0.96023214 0.62962788 0.98593825 1.         1.        ]
#  [0.99070334 0.99613237 0.95134324 0.96906483 0.99071968 1.         1.        ]
#  [0.99272209 0.99126315 0.98992145 0.97269112 0.99159932 1.         1.        ]
#  [0.99678254 0.99208176 0.98499972 0.98822159 0.99167556 1.         1.        ]
#  [0.99383235 0.99264973 0.99330926 0.98434514 0.99176496 1.         1.        ]
#  [0.98074704 0.99267042 0.9892903  0.97981584 0.99135345 1.         1.        ]
#  [0.9850145  0.98710221 0.79596233 0.95927954 0.98462397 1.         1.        ]
#  [0.91937858 0.99469793 0.98909378 0.98875391 0.98961055 1.         1.        ]
#  [0.97710198 0.99222481 0.98522353 0.93696707 0.99092537 1.         1.        ]
#  [0.99339139 0.99290138 0.98753291 0.97556317 0.99159276 1.         1.        ]
#  [0.9969483  0.99246663 0.99045724 0.98466152 0.99177772 1.         1.        ]
#  [0.99319249 0.99080545 0.94749552 0.9609372  0.99060178 1.         1.        ]
#  [0.99025601 0.99182385 0.98900807 0.98461795 0.99158955 1.         1.        ]
#  [0.99680471 0.98901665 0.9665668  0.98625457 0.99120528 1.         1.        ]
#  [0.996333   0.99153417 0.93483657 0.98505974 0.99037111 1.         1.        ]
#  [0.98073131 0.98742676 0.95839792 0.94869965 0.99044997 1.         1.        ]
#  [0.99651539 0.99191999 0.98348457 0.98301643 0.99161363 1.         1.        ]
#  [0.99254274 0.99284077 0.98886222 0.9868347  0.99165785 1.         1.        ]
#  [0.99418616 0.98794228 0.99185431 0.99117392 0.99173754 1.         1.        ]
#  [0.98252845 0.99184942 0.97968483 0.96347988 0.99109656 1.         1.        ]
#  [0.99479276 0.99068481 0.98747396 0.9813928  0.9916386  1.         1.        ]
#  [0.99629885 0.99313498 0.85141993 0.97096145 0.98752296 1.         1.        ]
#  [0.94863141 0.94080418 0.12653247 0.87001371 0.83879691 1.         1.        ]
#  [0.99340111 0.99062854 0.98780137 0.97432536 0.99157554 1.         1.        ]
#  [0.98790926 0.99334371 0.98523444 0.98311663 0.99145854 1.         1.        ]
#  [0.96342367 0.98997015 0.98755938 0.97424603 0.99082321 1.         1.        ]
#  [0.99728203 0.99225426 0.98886502 0.99053603 0.99177891 1.         1.        ]
#  [0.992149   0.99029166 0.99185961 0.97759354 0.99164522 1.         1.        ]
#  [0.99209881 0.99194592 0.9891901  0.95970678 0.99150169 1.         1.        ]
#  [0.99478972 0.99284607 0.98331547 0.98371661 0.99158067 1.         1.        ]
#  [0.99162275 0.98866999 0.97530138 0.9698202  0.99123198 1.         1.        ]
#  [0.99198908 0.97452962 0.97322726 0.94966376 0.99095809 1.         1.        ]
#  [0.99628192 0.99349558 0.99003601 0.98946977 0.99178576 1.         1.        ]
#  [0.97911602 0.99223703 0.98354971 0.92626381 0.99086875 1.         1.        ]
#  [0.997666   0.99085087 0.94801348 0.98469377 0.99076205 1.         1.        ]
#  [0.98989797 0.98570538 0.98442233 0.95568532 0.99128193 1.         1.        ]
#  [0.99368745 0.98870879 0.98232907 0.98778045 0.99151587 1.         1.        ]
#  [0.99343586 0.98542714 0.97756869 0.96868747 0.99129188 1.         1.        ]
#  [0.99331641 0.99433881 0.98750532 0.98220086 0.99163616 1.         1.        ]
#  [0.994699   0.99474442 0.98742104 0.98388517 0.99167764 1.         1.        ]
#  [0.96599948 0.98605251 0.94553983 0.95717448 0.98973083 1.         1.        ]
#  [0.98800313 0.99368155 0.9461776  0.97058165 0.99050188 1.         1.        ]
#  [0.99186593 0.98303556 0.95721662 0.9637695  0.99075049 1.         1.        ]
#  [0.99418008 0.99235183 0.99110013 0.98114407 0.99170923 1.         1.        ]
#  [0.9903875  0.9925558  0.97181511 0.97825545 0.99119741 1.         1.        ]
#  [0.97896385 0.9873777  0.98275352 0.97846258 0.9911139  1.         1.        ]
#  [0.99860471 0.99716705 0.99379694 0.98905957 0.99193662 1.         1.        ]
#  [0.88100564 0.9090749  0.95882416 0.89029926 0.9853009  1.         1.        ]
#  [0.99205375 0.9891867  0.91212994 0.97943395 0.98952675 1.         1.        ]
#  [0.98820913 0.99278557 0.98939949 0.98020017 0.9915362  1.         1.        ]
#  [0.99381542 0.99314827 0.9892236  0.98470277 0.99168724 1.         1.        ]
#  [0.99363518 0.9927451  0.98648918 0.9879005  0.99163675 1.         1.        ]
#  [0.99389428 0.9945392  0.92786998 0.95772743 0.99012071 1.         1.        ]
#  [0.9892841  0.97496766 0.83360553 0.97813076 0.98622423 1.         1.        ]
#  [0.99634653 0.99080539 0.94685364 0.97680897 0.99069405 1.         1.        ]
#  [0.99481082 0.99369472 0.9887473  0.97607291 0.99165821 1.         1.        ]
#  [0.99232399 0.99548906 0.9478361  0.967251   0.99065977 1.         1.        ]
#  [0.99036193 0.99585009 0.98459089 0.97379875 0.99147391 1.         1.        ]
#  [0.99482203 0.99402183 0.99581981 0.99004447 0.99187648 1.         1.        ]
#  [0.98866707 0.99421567 0.98347306 0.96988916 0.99137759 1.         1.        ]
#  [0.99525923 0.9912219  0.9665305  0.98111516 0.991189   1.         1.        ]
#  [0.99411327 0.99194336 0.98576385 0.97883886 0.99158347 1.         1.        ]
#  [0.99544889 0.94634461 0.97883159 0.96082151 0.99095476 1.         1.        ]
#  [0.99797922 0.99452811 0.99198288 0.99197644 0.99188316 1.         1.        ]
#  [0.96869242 0.97944301 0.09695588 0.85016346 0.83791798 1.         1.        ]
#  [0.99521565 0.9908337  0.98914123 0.96661544 0.99160177 1.         1.        ]
#  [0.99649173 0.9923929  0.99212557 0.98396075 0.99179691 1.         1.        ]
#  [0.99198252 0.99199414 0.99008304 0.95717686 0.99150354 1.         1.        ]
#  [0.99792719 0.99491912 0.98963135 0.99290085 0.99183989 1.         1.        ]
#  [0.99080396 0.99028522 0.95966554 0.98884982 0.99091405 1.         1.        ]
#  [0.98320425 0.99397212 0.9837743  0.99141943 0.99135077 1.         1.        ]
#  [0.99741888 0.9933449  0.99161869 0.99075681 0.99184865 1.         1.        ]
#  [0.99348599 0.99103433 0.99158329 0.96923143 0.9916293  1.         1.        ]
#  [0.99389523 0.9932121  0.98884845 0.98121899 0.99166346 1.         1.        ]
#  [0.99741733 0.99297333 0.9915877  0.99050361 0.991844   1.         1.        ]
#  [0.98990822 0.99268299 0.99185342 0.97892547 0.99161822 1.         1.        ]
#  [0.97459692 0.96881658 0.73288441 0.92322642 0.98030365 1.         1.        ]
#  [0.98195672 0.98995626 0.97271168 0.95387578 0.99085909 1.         1.        ]
#  [0.99375761 0.99494994 0.9847151  0.96768057 0.99151349 1.         1.        ]
#  [0.99327129 0.99172533 0.99279732 0.98147273 0.99172038 1.         1.        ]
#  [0.99466997 0.98829579 0.98663574 0.9564957  0.99146187 1.         1.        ]
#  [0.99787879 0.99625361 0.99088329 0.99069679 0.99186486 1.         1.        ]
#  [0.99690384 0.99283385 0.99327236 0.98857403 0.99185598 1.         1.        ]
#  [0.99184376 0.99233562 0.98369044 0.98181975 0.99150622 1.         1.        ]
#  [0.99752253 0.99450821 0.99261355 0.99080932 0.99187982 1.         1.        ]
#  [0.98838055 0.994313   0.9902389  0.99328738 0.99162567 1.         1.        ]
#  [0.98944992 0.99345654 0.98952752 0.99220043 0.99162477 1.         1.        ]
#  [0.99284947 0.99495161 0.98813421 0.94654655 0.99144351 1.         1.        ]
#  [0.99484837 0.99289376 0.99197376 0.98294199 0.99175525 1.         1.        ]
#  [0.98842061 0.98936647 0.98362732 0.98096532 0.99139458 1.         1.        ]
#  [0.99871278 0.99309653 0.9891755  0.99137455 0.9918285  1.         1.        ]
#  [0.99653804 0.99266809 0.99338758 0.994048   0.99187237 1.         1.        ]
#  [0.99352103 0.99514574 0.98854256 0.98130774 0.99166304 1.         1.        ]
#  [0.99877101 0.99468625 0.99315721 0.99457234 0.99193656 1.         1.        ]
#  [0.99292105 0.99021238 0.99516869 0.96884918 0.99168181 1.         1.        ]
#  [0.99218118 0.98823452 0.99212646 0.98871124 0.99168891 1.         1.        ]
#  [0.98709375 0.99184978 0.9705165  0.96307385 0.99100477 1.         1.        ]
#  [0.99302012 0.99178445 0.98654735 0.98200697 0.99159026 1.         1.        ]
#  [0.98927259 0.99226862 0.94637537 0.98408645 0.99054557 1.         1.        ]
#  [0.99533588 0.99485117 0.99305516 0.99169004 0.99184579 1.         1.        ]
#  [0.9903667  0.98985541 0.95389742 0.94901377 0.99060452 1.         1.        ]
#  [0.99669844 0.99515247 0.97715604 0.9757539  0.99147046 1.         1.        ]
#  [0.99310488 0.99260861 0.99436188 0.98310328 0.99176311 1.         1.        ]
#  [0.99619281 0.99118561 0.98576063 0.98230559 0.99164391 1.         1.        ]
#  [0.99703526 0.9902615  0.99292988 0.99479371 0.99185842 1.         1.        ]
#  [0.99429178 0.99648666 0.99041557 0.99014837 0.99177355 1.         1.        ]
#  [0.99538839 0.99348229 0.99005753 0.99093002 0.99177092 1.         1.        ]
#  [0.99341339 0.9940877  0.99368346 0.99200213 0.99180955 1.         1.        ]
#  [0.99040997 0.99483335 0.99123389 0.98457414 0.99166232 1.         1.        ]
#  [0.96082342 0.99146932 0.80637336 0.82017839 0.98373777 1.         1.        ]
#  [0.98788422 0.98920947 0.98453736 0.97366148 0.99136525 1.         1.        ]
#  [0.98690003 0.9949491  0.98924434 0.98658061 0.9915477  1.         1.        ]
#  [0.99299318 0.99051076 0.993958   0.98443884 0.99174458 1.         1.        ]
#  [0.99451077 0.99434185 0.98778009 0.98385507 0.99167764 1.         1.        ]
#  [0.99531376 0.99318874 0.98948753 0.98015416 0.99170285 1.         1.        ]
#  [0.9933269  0.99301636 0.97171551 0.98392755 0.99129075 1.         1.        ]
#  [0.9918378  0.98795033 0.98317611 0.98570782 0.99147511 1.         1.        ]
#  [0.99463743 0.98879403 0.9812035  0.87473482 0.99069065 1.         1.        ]
#  [0.9862662  0.99350327 0.98394483 0.98032516 0.99138051 1.         1.        ]
#  [0.98620367 0.99514741 0.98351568 0.98043138 0.99138361 1.         1.        ]
#  [0.99645054 0.99033254 0.9719587  0.98794299 0.99134684 1.         1.        ]
#  [0.99331081 0.99396437 0.98988461 0.98923409 0.99171591 1.         1.        ]
#  [0.98875111 0.9971084  0.98982543 0.99083602 0.99163848 1.         1.        ]
#  [0.99815816 0.98981851 0.99137771 0.99146301 0.99183601 1.         1.        ]
#  [0.99523276 0.99296993 0.98849523 0.98486173 0.99170405 1.         1.        ]
#  [0.99173814 0.99388486 0.98743963 0.96149474 0.99148142 1.         1.        ]
#  [0.99522424 0.98882347 0.98918331 0.98758519 0.99169874 1.         1.        ]
#  [0.99712878 0.99432677 0.99188787 0.98524076 0.99182659 1.         1.        ]
#  [0.9968341  0.99375242 0.9926824  0.99107802 0.99186146 1.         1.        ]
#  [0.98380303 0.99289376 0.97724253 0.95901811 0.99105698 1.         1.        ]
#  [0.99553359 0.97969282 0.86966342 0.98209697 0.98795986 1.         1.        ]
#  [0.98887384 0.98910195 0.9534381  0.76943386 0.98881483 1.         1.        ]
#  [0.9948743  0.99224299 0.99280012 0.98772264 0.9917928  1.         1.        ]
#  [0.99090487 0.98921973 0.98953015 0.99031901 0.99161786 1.         1.        ]
#  [0.99347913 0.99546009 0.9887709  0.9873088  0.99170059 1.         1.        ]
#  [0.98136544 0.98691678 0.96766859 0.92612779 0.99053335 1.         1.        ]
#  [0.97828853 0.98555297 0.96502542 0.96580696 0.99061501 1.         1.        ]
#  [0.99505192 0.99268019 0.98875064 0.97219312 0.99163467 1.         1.        ]
#  [0.98916149 0.9912442  0.98447478 0.96817511 0.99137902 1.         1.        ]
#  [0.99673176 0.99228066 0.99240583 0.99296594 0.99184936 1.         1.        ]
#  [0.99545419 0.99134946 0.99425173 0.99025565 0.99183995 1.         1.        ]
#  [0.99593168 0.99281949 0.99014974 0.98571843 0.99175674 1.         1.        ]
#  [0.99297923 0.98622108 0.96463656 0.94494963 0.99085641 1.         1.        ]
#  [0.96413922 0.9926852  0.98565125 0.9770686  0.99083906 1.         1.        ]
#  [0.98267096 0.99028134 0.98054296 0.91939449 0.99083382 1.         1.        ]
#  [0.99399346 0.99250925 0.9914698  0.9893139  0.99175394 1.         1.        ]
#  [0.99011081 0.98996478 0.92354119 0.884727   0.98937702 1.         1.        ]
#  [0.99337232 0.99352396 0.98870695 0.95487636 0.99150443 1.         1.        ]
#  [0.99394917 0.98869085 0.95836824 0.98603177 0.99093062 1.         1.        ]
#  [0.96420193 0.99548185 0.97835404 0.97268856 0.99067289 1.         1.        ]
#  [0.99483138 0.99223936 0.98355573 0.95730728 0.99143469 1.         1.        ]
#  [0.99591333 0.99038142 0.9680016  0.9679395  0.99117768 1.         1.        ]
#  [0.98126066 0.99566585 0.9844467  0.96793491 0.99122292 1.         1.        ]
#  [0.98441768 0.99295557 0.96941245 0.9380641  0.99077243 1.         1.        ]
#  [0.99763298 0.99185139 0.99142879 0.99434018 0.99185187 1.         1.        ]
#  [0.99199367 0.99434012 0.98920411 0.95694834 0.99150127 1.         1.        ]
#  [0.98817539 0.99109441 0.9852314  0.96620262 0.99135995 1.         1.        ]
#  [0.99035943 0.99388665 0.99090052 0.97924864 0.99161935 1.         1.        ]
#  [0.99190825 0.99213034 0.99095702 0.97522449 0.99162185 1.         1.        ]
#  [0.99250728 0.99471575 0.98972219 0.98539436 0.99168259 1.         1.        ]
#  [0.99316144 0.99236453 0.97232717 0.78524864 0.98957425 1.         1.        ]
#  [0.99445421 0.98971444 0.98557729 0.98012507 0.99157822 1.         1.        ]
#  [0.99709642 0.99058443 0.99275547 0.99353361 0.99185395 1.         1.        ]
#  [0.99445599 0.99295712 0.99247205 0.98425841 0.99176377 1.         1.        ]
#  [0.99360305 0.99289364 0.96595544 0.94873095 0.99098277 1.         1.        ]
#  [0.97041851 0.97474504 0.98440289 0.9809497  0.99083203 1.         1.        ]
#  [0.9949944  0.98660094 0.98947841 0.99338704 0.99170452 1.         1.        ]
#  [0.99333149 0.99720711 0.98925471 0.98999363 0.99173188 1.         1.        ]
#  [0.98959959 0.99462318 0.99074966 0.97974169 0.99160683 1.         1.        ]
#  [0.99147028 0.99180704 0.97426403 0.97789508 0.99127108 1.         1.        ]
#  [0.9969998  0.99223197 0.99111336 0.98945296 0.99181449 1.         1.        ]
#  [0.99647719 0.99317461 0.98408991 0.98647201 0.99165094 1.         1.        ]
#  [0.995983   0.99293959 0.98609829 0.96310067 0.9915517  1.         1.        ]
#  [0.99597758 0.99095786 0.98683178 0.98599303 0.9916774  1.         1.        ]
#  [0.99587882 0.99353433 0.98551404 0.97959787 0.99163419 1.         1.        ]
#  [0.98147476 0.99340147 0.9879781  0.97102678 0.99130362 1.         1.        ]
#  [0.98768812 0.98894483 0.98521811 0.98836797 0.99143785 1.         1.        ]
#  [0.99113256 0.99681467 0.98710597 0.99240017 0.99164093 1.         1.        ]
#  [0.99175322 0.98833686 0.98916    0.99025506 0.99162281 1.         1.        ]
#  [0.98890543 0.99588794 0.98735398 0.98266476 0.99154562 1.         1.        ]
#  [0.98534679 0.98949987 0.36820206 0.93276078 0.93767822 1.         1.        ]
#  [0.99386591 0.9947359  0.98765904 0.98670435 0.99167812 1.         1.        ]
#  [0.99465889 0.99158293 0.96816301 0.91266221 0.99080288 1.         1.        ]
#  [0.99384379 0.99538559 0.98661959 0.97079337 0.99157554 1.         1.        ]
#  [0.99266863 0.99049145 0.98636276 0.98182201 0.99156767 1.         1.        ]
#  [0.98668242 0.99044341 0.26753879 0.56051373 0.90182543 1.         1.        ]
#  [0.99359918 0.98427504 0.95081437 0.96536404 0.99064636 1.         1.        ]
#  [0.99734384 0.99350464 0.99247557 0.86831605 0.99094498 1.         1.        ]
#  [0.98575252 0.98599964 0.49532783 0.91359514 0.95934159 1.         1.        ]
#  [0.99540776 0.99275571 0.97935563 0.98528314 0.99151611 1.         1.        ]
#  [0.98224938 0.98345411 0.97049415 0.94714868 0.99072462 1.         1.        ]
#  [0.9739362  0.99025726 0.94130582 0.9549579  0.98989403 1.         1.        ]
#  [0.99474561 0.99211943 0.98816198 0.97153372 0.99160808 1.         1.        ]
#  [0.99594182 0.99357998 0.99194795 0.98051721 0.99177146 1.         1.        ]
#  [0.99107647 0.9925862  0.97371656 0.936575   0.99101722 1.         1.        ]
#  [0.99094558 0.9931879  0.99028414 0.95582891 0.99148524 1.         1.        ]
#  [0.98640722 0.98366416 0.97188908 0.86573994 0.99016845 1.         1.        ]
#  [0.99350441 0.9855715  0.98710501 0.99131435 0.99160254 1.         1.        ]
#  [0.99718362 0.99446094 0.98630512 0.96084839 0.99158114 1.         1.        ]
#  [0.98506802 0.97775364 0.15498134 0.85003901 0.86948442 1.         1.        ]
#  [0.9967519  0.9951368  0.97558039 0.98719668 0.99148554 1.         1.        ]
#  [0.99109417 0.99177825 0.98934048 0.96379328 0.99150413 1.         1.        ]
#  [0.99372685 0.98347974 0.98724139 0.96728456 0.99147958 1.         1.        ]
#  [0.98842353 0.99557626 0.957111   0.91758132 0.99047273 1.         1.        ]
#  [0.99423665 0.99353713 0.97714716 0.95911252 0.99130607 1.         1.        ]
#  [0.992679   0.99322093 0.9449029  0.99018574 0.99059677 1.         1.        ]
#  [0.98856759 0.99999821 0.97537541 0.9899587  0.99134171 1.         1.        ]
#  [0.99359506 0.98827517 0.98317969 0.98606908 0.9915216  1.         1.        ]
#  [0.9872458  0.98738307 0.98660278 0.97533619 0.9913891  1.         1.        ]
#  [0.99762875 0.99219924 0.94813478 0.98194396 0.99077749 1.         1.        ]
#  [0.99099696 0.99261194 0.96967602 0.98222142 0.99118042 1.         1.        ]
#  [0.99343055 0.9911021  0.95986724 0.98304236 0.99098176 1.         1.        ]
#  [0.99377877 0.98734599 0.91422355 0.92207009 0.98948491 1.         1.        ]
#  [0.99519205 0.99248874 0.98806792 0.99302375 0.99172485 1.         1.        ]
#  [0.99650782 0.99177682 0.97315085 0.98203939 0.99138194 1.         1.        ]
#  [0.9910512  0.99408817 0.96812451 0.96740949 0.9910906  1.         1.        ]
#  [0.99502546 0.99153882 0.99093103 0.9830026  0.99172884 1.         1.        ]
#  [0.9913345  0.99412388 0.97835815 0.97291982 0.99134815 1.         1.        ]
#  [0.99688333 0.99451268 0.9875164  0.98108929 0.99171263 1.         1.        ]
#  [0.99484152 0.98705369 0.89606851 0.96043241 0.98902231 1.         1.        ]
#  [0.98941225 0.83155537 0.87071854 0.94508815 0.98472476 1.         1.        ]
# ...
#  [0.99097401 0.99442744 0.99199909 0.97639537 0.99164462 1.         1.        ]
#  [0.99702877 0.99313265 0.97202784 0.95838851 0.99125457 1.         1.        ]
#  [0.84524459 0.94197375 0.92698437 0.26966733 0.96008545 1.         1.        ]
#  [0.97502327 0.9823842  0.90359831 0.61529249 0.98413813 1.         1.        ]
#  [0.959934   0.9757638  0.95279354 0.95178354 0.98960739 1.         1.        ]
#  [0.99645847 0.99228293 0.98478991 0.97637004 0.99160552 1.         1.        ]
#  [0.88068569 0.94633663 0.96132207 0.954162   0.98648643 1.         1.        ]
#  [0.98671585 0.94999212 0.98797697 0.9645412  0.99099988 1.         1.        ]
#  [0.95464891 0.80783755 0.9678629  0.96885151 0.98667234 1.         1.        ]
#  [0.99657506 0.99661309 0.98316342 0.95059979 0.99145979 1.         1.        ]
#  [0.98362505 0.93356252 0.97774029 0.93290573 0.99030012 1.         1.        ]
#  [0.99270004 0.97215974 0.9545998  0.91339773 0.99027091 1.         1.        ]
#  [0.99220848 0.99548233 0.99181491 0.97463202 0.99166715 1.         1.        ]
#  [0.88859642 0.98255539 0.80319893 0.86803997 0.98019868 1.         1.        ]
#  [0.9990496  0.99164587 0.98857158 0.97938526 0.99175203 1.         1.        ]
#  [0.99484599 0.98098803 0.98761356 0.97989172 0.99156135 1.         1.        ]
#  [0.88815349 0.40146154 0.96719533 0.97243834 0.96160865 1.         1.        ]
#  [0.99659061 0.87978661 0.69380701 0.95575094 0.9758603  1.         1.        ]
#  [0.74073213 0.86365974 0.97590655 0.96190488 0.97554564 1.         1.        ]
#  [0.97068381 0.98526657 0.88677365 0.74644572 0.98614961 1.         1.        ]
#  [0.94172484 0.76121336 0.94010568 0.98337114 0.98389345 1.         1.        ]
#  [0.99417913 0.99364412 0.1546814  0.97073537 0.8758778  1.         1.        ]
#  [0.97130322 0.94642341 0.96326858 0.97097754 0.98999327 1.         1.        ]
#  [0.99543375 0.94287342 0.94826961 0.96681243 0.99007243 1.         1.        ]
#  [0.75666505 0.91132104 0.98790026 0.88111824 0.9778716  1.         1.        ]
#  [0.99652785 0.98702544 0.89864486 0.96241134 0.98915243 1.         1.        ]
#  [0.3678124  0.87590683 0.97478038 0.95950228 0.88420987 1.         1.        ]
#  [0.98222291 0.09035931 0.86408669 0.95196551 0.91210794 1.         1.        ]
#  [0.95939386 0.95847714 0.9672364  0.85128736 0.9888798  1.         1.        ]
#  [0.97585797 0.12454838 0.93681568 0.84383744 0.93200248 1.         1.        ]
#  [0.96948647 0.98912293 0.96786308 0.89505017 0.99001557 1.         1.        ]
#  [0.41272771 0.94493973 0.89930063 0.95003718 0.8937034  1.         1.        ]
#  [0.98204696 0.99072015 0.91907418 0.94520062 0.98947453 1.         1.        ]
#  [0.99141896 0.96463913 0.97852832 0.92849451 0.99082214 1.         1.        ]
#  [0.99096394 0.99338949 0.96106559 0.94669592 0.99080169 1.         1.        ]
#  [0.99494535 0.98490405 0.90462935 0.94308776 0.98927301 1.         1.        ]
#  [0.98378527 0.98115528 0.97696781 0.93440503 0.99081123 1.         1.        ]
#  [0.99306583 0.99315876 0.95527381 0.95772499 0.99078816 1.         1.        ]
#  [0.90299016 0.9799875  0.92494386 0.92173004 0.98658472 1.         1.        ]
#  [0.95490748 0.24687408 0.78738749 0.77396059 0.92178309 1.         1.        ]
#  [0.98293006 0.99373537 0.96985495 0.95742244 0.99086958 1.         1.        ]
#  [0.99622536 0.97827393 0.97213316 0.97640365 0.99121886 1.         1.        ]
#  [0.99108958 0.97154868 0.60529411 0.79188198 0.97131515 1.         1.        ]
#  [0.99706906 0.93416977 0.94470596 0.96015584 0.98985845 1.         1.        ]
#  [0.97680128 0.43778676 0.95745301 0.94897264 0.97102827 1.         1.        ]
#  [0.91763115 0.95038712 0.95088655 0.97414547 0.98788667 1.         1.        ]
#  [0.98878598 0.97584325 0.88784236 0.98466474 0.98838258 1.         1.        ]
#  [0.87529826 0.97472566 0.90234035 0.80836695 0.98326588 1.         1.        ]
#  [0.97460395 0.97837526 0.93177599 0.94885522 0.98949242 1.         1.        ]
#  [0.99201339 0.99173778 0.97687984 0.94517761 0.99115318 1.         1.        ]
#  [0.74327314 0.96132553 0.83793306 0.93778229 0.96953595 1.         1.        ]
#  [0.99118245 0.9726752  0.92771864 0.96363914 0.98976439 1.         1.        ]
#  [0.97945261 0.9911204  0.97081649 0.90079701 0.99040717 1.         1.        ]
#  [0.98489112 0.99581933 0.9864893  0.96657133 0.99134624 1.         1.        ]
#  [0.98988932 0.98476911 0.94779497 0.92514551 0.99023533 1.         1.        ]
#  [0.98282164 0.37167305 0.98435116 0.97310251 0.96901542 1.         1.        ]
#  [0.9832961  0.92181045 0.90631944 0.81043243 0.98708731 1.         1.        ]
#  [0.98846442 0.85695148 0.96599644 0.91439575 0.98860532 1.         1.        ]
#  [0.98772162 0.98965889 0.92494893 0.90318286 0.98948705 1.         1.        ]
#  [0.99120975 0.99278694 0.95398241 0.93202347 0.9905383  1.         1.        ]
#  [0.98453993 0.72639847 0.88028193 0.91479152 0.98165649 1.         1.        ]
#  [0.98800474 0.98915184 0.98584169 0.92954415 0.99113548 1.         1.        ]
#  [0.98990357 0.9919154  0.98099798 0.96642393 0.99131811 1.         1.        ]
#  [0.99037182 0.99293149 0.98536402 0.96571821 0.99142426 1.         1.        ]
#  [0.99781883 0.98980415 0.99438417 0.9807654  0.99183631 1.         1.        ]
#  [0.98291689 0.93138671 0.52143198 0.84116727 0.95899886 1.         1.        ]
#  [0.99067008 0.98873669 0.98281372 0.97925764 0.9914189  1.         1.        ]
#  [0.91404444 0.88784105 0.6960485  0.89683729 0.97077024 1.         1.        ]
#  [0.99440259 0.9936558  0.98481834 0.97043568 0.99153644 1.         1.        ]
#  [0.97162104 0.74962699 0.86293143 0.92231381 0.98116046 1.         1.        ]
#  [0.92260581 0.10278574 0.9500525  0.90131307 0.92118174 1.         1.        ]
#  [0.99407357 0.99224019 0.98930538 0.98686582 0.99169838 1.         1.        ]
#  [0.96463436 0.07567829 0.95284528 0.89684391 0.92448163 1.         1.        ]
#  [0.92883891 0.68239695 0.95988017 0.9158144  0.98129112 1.         1.        ]
#  [0.95718133 0.97978824 0.95116431 0.73702949 0.98721188 1.         1.        ]
#  [0.99518871 0.86329579 0.34936219 0.94973266 0.92095232 1.         1.        ]
#  [0.98530012 0.98226112 0.97338349 0.96652669 0.99096566 1.         1.        ]
#  [0.98701167 0.98978639 0.96584553 0.94367081 0.99076533 1.         1.        ]
#  [0.99275619 0.97891349 0.87463629 0.8813985  0.98785114 1.         1.        ]
#  [0.99377728 0.99722987 0.95953929 0.97347742 0.99101865 1.         1.        ]
#  [0.98775804 0.76609665 0.84470022 0.95415759 0.98147953 1.         1.        ]
#  [0.99265116 0.99423403 0.98465526 0.97976571 0.99154848 1.         1.        ]
#  [0.9717353  0.95729911 0.83323705 0.92268008 0.98526645 1.         1.        ]
#  [0.98746067 0.96837217 0.9281038  0.89634943 0.98929214 1.         1.        ]
#  [0.99450076 0.99513429 0.53923494 0.96076196 0.96616685 1.         1.        ]
#  [0.964028   0.94783616 0.76184368 0.83840948 0.98089206 1.         1.        ]
#  [0.94081557 0.66648203 0.91136581 0.65873456 0.97590375 1.         1.        ]
#  [0.93167388 0.95479822 0.96684217 0.90006274 0.98841286 1.         1.        ]
#  [0.9891398  0.99172455 0.89819014 0.72547424 0.98691183 1.         1.        ]
#  [0.99635184 0.73531675 0.9754191  0.94332242 0.98616153 1.         1.        ]
#  [0.98100007 0.9941619  0.98609734 0.9629907  0.99121332 1.         1.        ]
#  [0.98883724 0.87678713 0.98124599 0.92437065 0.98945582 1.         1.        ]
#  [0.94506121 0.98891139 0.9116534  0.57551575 0.98241168 1.         1.        ]
#  [0.99809438 0.84525132 0.88003945 0.57806343 0.98113704 1.         1.        ]
#  [0.98861212 0.9730618  0.76866055 0.9104113  0.9830386  1.         1.        ]
#  [0.87750781 0.92542034 0.97879332 0.89148867 0.98605502 1.         1.        ]
#  [0.98259097 0.33584699 0.71773511 0.16626906 0.88877404 1.         1.        ]
#  [0.97312331 0.99419987 0.99013352 0.94124925 0.99096829 1.         1.        ]
#  [0.97542453 0.99043274 0.92914706 0.90720344 0.98929483 1.         1.        ]
#  [0.80135041 0.99038625 0.97354478 0.8623268  0.98264086 1.         1.        ]
#  [0.90163964 0.98387086 0.92986202 0.94848102 0.98693258 1.         1.        ]
#  [0.86051089 0.932895   0.85964674 0.94860202 0.98120153 1.         1.        ]
#  [0.99036825 0.99179417 0.98180872 0.96198243 0.9913193  1.         1.        ]
#  [0.98358661 0.98506504 0.97535139 0.9379611  0.99082273 1.         1.        ]
#  [0.98216999 0.99450928 0.96313959 0.94802588 0.99064898 1.         1.        ]
#  [0.98376566 0.91408229 0.9202795  0.97434062 0.98835438 1.         1.        ]
#  [0.83116394 0.23301783 0.95093346 0.95220405 0.9284777  1.         1.        ]
#  [0.96632415 0.96565521 0.93831831 0.93970895 0.98922735 1.         1.        ]
#  [0.88175082 0.97234321 0.93367225 0.94297642 0.98598093 1.         1.        ]
#  [0.99708098 0.983334   0.91177243 0.69276208 0.9868592  1.         1.        ]
#  [0.98399514 0.87815487 0.9865219  0.98144162 0.9896633  1.         1.        ]
#  [0.9451533  0.97366929 0.73753554 0.88008451 0.9792996  1.         1.        ]
#  [0.93225026 0.99086797 0.98655301 0.95395166 0.98973936 1.         1.        ]
#  [0.99643385 0.97473776 0.98295826 0.97150862 0.99141014 1.         1.        ]
#  [0.85442293 0.9899714  0.95615631 0.91602892 0.98555553 1.         1.        ]
#  [0.98719054 0.10544624 0.84088504 0.51361912 0.89798409 1.         1.        ]
#  [0.9900288  0.98698795 0.68920451 0.87912464 0.97870171 1.         1.        ]
#  [0.95481205 0.79040867 0.91825759 0.84545976 0.98400319 1.         1.        ]
#  [0.99557281 0.99079531 0.98807073 0.97140461 0.9916144  1.         1.        ]
#  [0.9547292  0.98156869 0.96364146 0.92638838 0.98963362 1.         1.        ]
#  [0.96492064 0.98914015 0.95749468 0.95897388 0.99005151 1.         1.        ]
#  [0.96123844 0.98543638 0.96333385 0.95454353 0.99003649 1.         1.        ]
#  [0.949449   0.9780677  0.84953988 0.926925   0.98562074 1.         1.        ]
#  [0.98992819 0.98915976 0.985385   0.96659005 0.99139184 1.         1.        ]
#  [0.9555462  0.9912163  0.97645217 0.96322984 0.99029583 1.         1.        ]
#  [0.98413926 0.98335129 0.94299531 0.96164113 0.9901886  1.         1.        ]
#  [0.96557993 0.13155474 0.25554055 0.92992944 0.60095096 0.         1.        ]
#  [0.95316762 0.98378563 0.86180604 0.47437629 0.97737944 1.         1.        ]
#  [0.99343657 0.98369092 0.97832823 0.98158252 0.99135655 1.         1.        ]
#  [0.98899508 0.82758373 0.93317866 0.56056309 0.9818086  1.         1.        ]
#  [0.97047269 0.65003669 0.94615978 0.87753314 0.98114735 1.         1.        ]
#  [0.98889416 0.98190778 0.94532448 0.9609763  0.9903506  1.         1.        ]
#  [0.9170602  0.94136107 0.96377802 0.76457638 0.98597139 1.         1.        ]
#  [0.9971112  0.98985088 0.94300884 0.97515148 0.99059182 1.         1.        ]
#  [0.98568952 0.98042566 0.93923748 0.90608996 0.98973507 1.         1.        ]
#  [0.9752906  0.96204841 0.97659224 0.96727115 0.99059749 1.         1.        ]
#  [0.98497713 0.9647876  0.96474487 0.97960097 0.9906382  1.         1.        ]
#  [0.97233325 0.98126203 0.95959699 0.96294004 0.99026477 1.         1.        ]
#  [0.99325103 0.98814672 0.98663843 0.97817957 0.99155068 1.         1.        ]
#  [0.98616576 0.96804994 0.96197319 0.96729863 0.99059093 1.         1.        ]
#  [0.97430336 0.97979569 0.97560877 0.84323281 0.98964626 1.         1.        ]
#  [0.9936133  0.99366552 0.99079472 0.9629426  0.99159956 1.         1.        ]
#  [0.94531614 0.96116179 0.92610598 0.89797157 0.98784661 1.         1.        ]
#  [0.9820888  0.98793566 0.9569422  0.81807017 0.98926675 1.         1.        ]
#  [0.99736816 0.98670989 0.95596659 0.95652252 0.9908396  1.         1.        ]
#  [0.99534458 0.34007305 0.97865981 0.96605766 0.96712953 1.         1.        ]
#  [0.99666721 0.87943345 0.97777402 0.93954664 0.98966867 1.         1.        ]
#  [0.98698205 0.99181414 0.98975033 0.96811664 0.9914428  1.         1.        ]
#  [0.96219397 0.96930861 0.8139205  0.93614811 0.98427373 1.         1.        ]
#  [0.97938728 0.98465616 0.96819502 0.97854108 0.99076653 1.         1.        ]
#  [0.98768938 0.97574347 0.98964018 0.98146409 0.99139774 1.         1.        ]
#  [0.9618631  0.98719072 0.89673895 0.92109364 0.98798269 1.         1.        ]
#  [0.9905737  0.9871316  0.97601402 0.92996883 0.99097061 1.         1.        ]
#  [0.97865218 0.96799153 0.94577479 0.95842332 0.98992795 1.         1.        ]
#  [0.98243111 0.10634882 0.58901578 0.87251103 0.82431298 1.         1.        ]
#  [0.96920973 0.92566699 0.88437366 0.84103167 0.98628336 1.         1.        ]
#  [0.9760651  0.98555815 0.98721629 0.94115323 0.99090677 1.         1.        ]
#  [0.9060787  0.10442711 0.88152224 0.92566067 0.90259248 1.         1.        ]
#  [0.98461121 0.81822675 0.9823125  0.91455585 0.98804808 1.         1.        ]
#  [0.9929778  0.98518109 0.94144434 0.9065842  0.99002796 1.         1.        ]
#  [0.98589247 0.70706773 0.34580666 0.18481226 0.85569608 1.         1.        ]
#  [0.99338853 0.99199343 0.99001503 0.95946473 0.99154681 1.         1.        ]
#  [0.98931199 0.98671561 0.7917847  0.88026446 0.98453641 1.         1.        ]
#  [0.97609633 0.30894145 0.81241405 0.81837714 0.94086319 1.         1.        ]
#  [0.98569804 0.98411858 0.93560308 0.90566874 0.98967493 1.         1.        ]
#  [0.98058015 0.96107626 0.91959053 0.94165599 0.9890393  1.         1.        ]
#  [0.98446518 0.97768706 0.96945679 0.89752328 0.99033231 1.         1.        ]
#  [0.99124759 0.98836297 0.90298843 0.89522994 0.98890626 1.         1.        ]
#  [0.99039334 0.9912951  0.97278148 0.96304244 0.99112898 1.         1.        ]
#  [0.80924261 0.70188916 0.60936594 0.81230664 0.93006951 1.         1.        ]
#  [0.9459374  0.98762244 0.78302908 0.87244159 0.98230803 1.         1.        ]
#  [0.98582804 0.98526937 0.97248983 0.94531757 0.99086004 1.         1.        ]
#  [0.98052788 0.99000311 0.98629886 0.94340837 0.99105865 1.         1.        ]
#  [0.99504566 0.97504675 0.97169363 0.97126794 0.9911288  1.         1.        ]
#  [0.96088898 0.98918557 0.9386211  0.97165018 0.98948312 1.         1.        ]
#  [0.9790172  0.99374324 0.96808898 0.89218444 0.99028593 1.         1.        ]
#  [0.92823344 0.7467224  0.88325661 0.90526682 0.98026115 1.         1.        ]
#  [0.99105972 0.99345052 0.96996784 0.95864666 0.99107385 1.         1.        ]
#  [0.98649514 0.98579526 0.97766417 0.9784773  0.99117494 1.         1.        ]
#  [0.97859144 0.90226161 0.95772839 0.92123073 0.98912239 1.         1.        ]
#  [0.98782057 0.99126804 0.98647761 0.87372333 0.99064445 1.         1.        ]
#  [0.97377157 0.95914871 0.95509285 0.93114829 0.98979259 1.         1.        ]
#  [0.92626244 0.97734022 0.88869148 0.28497371 0.96795404 1.         1.        ]
#  [0.95793599 0.71096033 0.74555534 0.84759355 0.97050285 1.         1.        ]
#  [0.99313557 0.98754495 0.97712177 0.95875263 0.99123311 1.         1.        ]
#  [0.98105091 0.4358288  0.75197005 0.20802327 0.91974211 1.         1.        ]
#  [0.99836677 0.99243635 0.98400784 0.98624772 0.991687   1.         1.        ]
#  [0.98026079 0.98589116 0.98207229 0.96157992 0.99103719 1.         1.        ]
#  [0.97640228 0.98317379 0.97813988 0.94405985 0.99072975 1.         1.        ]
#  [0.99109966 0.88304269 0.96694058 0.93047076 0.98932028 1.         1.        ]
#  [0.92400479 0.95466208 0.95324302 0.91815716 0.98788941 1.         1.        ]
#  [0.99523395 0.96612906 0.9892925  0.87367511 0.99061632 1.         1.        ]
#  [0.96520764 0.90776211 0.96871066 0.90514314 0.98896295 1.         1.        ]
#  [0.97780448 0.94177443 0.77202916 0.97252977 0.98199028 1.         1.        ]
#  [0.98224163 0.98833197 0.99121463 0.96919328 0.99134266 1.         1.        ]
#  [0.98726195 0.98881382 0.86643571 0.97716641 0.98776656 1.         1.        ]
#  [0.98716056 0.99159592 0.97477061 0.9663806  0.99111623 1.         1.        ]
#  [0.96458256 0.98907018 0.95626891 0.85622084 0.9892121  1.         1.        ]
#  [0.99500245 0.92233771 0.97327119 0.95537388 0.9904089  1.         1.        ]]
